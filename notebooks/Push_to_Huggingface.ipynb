# %%
import sys
sys.path.append('../src')

from wikidata_dumpreader import WikidataDumpReader
from wikidataLabelsDB import WikidataLabels
from multiprocessing import Manager
import asyncio
import gc
import os
import json
from datasets import Dataset

FILEPATH = os.getenv("FILEPATH", '../data/Wikidata/latest-all.json.bz2')
BATCH_SIZE = int(os.getenv("BATCH_SIZE", 5000))
PUSH_SIZE = int(os.getenv("PUSH_SIZE", 10000))
QUEUE_SIZE = int(os.getenv("QUEUE_SIZE", 10000))
NUM_PROCESSES = int(os.getenv("NUM_PROCESSES", 4))
SKIPLINES = 0

# %%
def save_labels_to_sqlite(item, data_batch, sqlitDBlock):
    if (item is not None):
        labels = WikidataLabels.clean_labels(item['labels'])
        labels = json.dumps(labels, separators=(',', ':'))
        data_batch.append({
            'id': item['id'],
            'labels': labels
        })

        with sqlitDBlock:
            if len(data_batch) > PUSH_SIZE:
                worked = WikidataLabels.add_bulk_labels(list(data_batch[:PUSH_SIZE]))
                if worked:
                    del data_batch[:PUSH_SIZE]
                    gc.collect()

async def run_processor(wikidata, bulk_ids, sqlitDBlock):
    await wikidata.run(lambda item: save_labels_to_sqlite(item, bulk_ids, sqlitDBlock), max_iterations=None, verbose=True)

multiprocess_manager = Manager()
sqlitDBlock = multiprocess_manager.Lock()
data_batch = multiprocess_manager.list()

wikidata = WikidataDumpReader(FILEPATH, num_processes=NUM_PROCESSES, batch_size=BATCH_SIZE, queue_size=QUEUE_SIZE, skiplines=SKIPLINES)

await run_processor(wikidata, data_batch, sqlitDBlock)

while len(data_batch) > 0:
    worked = WikidataLabels.add_bulk_labels(list(data_batch))
    if worked:
        data_batch[:] = []
    else:
        asyncio.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 24
#      21 sqlitDBlock = multiprocess_manager.Lock()
#      22 data_batch = multiprocess_manager.list()
# ---> 24 wikidata = WikidataDumpReader(FILEPATH, num_processes=NUM_PROCESSES, batch_size=BATCH_SIZE, queue_size=QUEUE_SIZE, skiplines=SKIPLINES)
#      26 await run_processor(wikidata, data_batch, sqlitDBlock)
#      28 while len(data_batch) > 0:
#
# TypeError: WikidataDumpReader.__init__() got an unexpected keyword argument 'batch_size'

# %%
def save_to_huggingface(item, data_batch, sqlitDBlock):
    global NUM_ITEMS
    global FILE_ID
    global FILE_SIZE
    global PUSH_SIZE

    if (item is not None):
        clean_entity = WikidataLabels.clean_entity(item)
        clean_entity = {
            'id': clean_entity['id'],
            'labels': json.dumps(clean_entity['labels'], separators=(',', ':')),
            'descriptions': json.dumps(clean_entity['descriptions'], separators=(',', ':')),
            'aliases': json.dumps(clean_entity['aliases'], separators=(',', ':')),
            'sitelinks': json.dumps(clean_entity['sitelinks'], separators=(',', ':')),
            'claims': json.dumps(clean_entity['claims'], separators=(',', ':'))
        }
        data_batch.append(clean_entity)

        with sqlitDBlock:
            if len(data_batch) > PUSH_SIZE:

                if NUM_ITEMS == 0:
                    with open(f'chunk_{FILE_ID}.json', 'w+') as f:
                        f.write('[\n')

                with open(f'chunk_{FILE_ID}.json', 'a+') as f:
                    text = json.dumps(list(data_batch[:PUSH_SIZE]), separators=(',', ':')).strip("[] ,")
                    f.write(text)
                    NUM_ITEMS += PUSH_SIZE

                    del data_batch[:PUSH_SIZE]
                    gc.collect()

                    if NUM_ITEMS >= FILE_SIZE:
                        f.write(']')
                    else:
                        f.write(",\n")

                if NUM_ITEMS >= FILE_SIZE:
                    data = Dataset.from_json(f'chunk_{FILE_ID}.json', split=f'chunk_{FILE_ID}')
                    data.push_to_hub("wikidata")

                    os.remove(f'chunk_{FILE_ID}.json')
                    FILE_ID += 1
                    NUM_ITEMS = 0

async def run_processor(wikidata, bulk_ids, sqlitDBlock):
    await wikidata.run(lambda item: save_to_huggingface(item, bulk_ids, sqlitDBlock), max_iterations=None, verbose=True)

multiprocess_manager = Manager()
sqlitDBlock = multiprocess_manager.Lock()
data_batch = multiprocess_manager.list()

wikidata = WikidataDumpReader(FILEPATH, num_processes=NUM_PROCESSES, batch_size=BATCH_SIZE, queue_size=QUEUE_SIZE, skiplines=SKIPLINES)

await run_processor(wikidata, data_batch, sqlitDBlock)

# %%
import gzip
import json
import sys
sys.path.append('../src')

from wikidata_dumpreader import WikidataDumpReader
from multiprocessing import Process, Value, Queue
import os

FILEPATH = os.getenv("FILEPATH", '../data/Wikidata/latest-all.json.bz2')
QUEUE_SIZE = int(os.getenv("QUEUE_SIZE", 2000))
NUM_PROCESSES = int(os.getenv("NUM_PROCESSES", 4))
SKIPLINES = 0

def save_to_queue(item, data_batch):
    if (item is not None):

        clean_claims = WikidataLabels._remove_keys(item.get('claims', {}), ['hash', 'snaktype', 'type', 'entity-type', 'numeric-id', 'qualifiers-order', 'snaks-order'])
        clean_claims = WikidataLabels._clean_datavalue(clean_claims)
        clean_claims = WikidataLabels._remove_keys(clean_claims, ['id'])
        # clean_claims = WikidataLabels._add_labels_to_claims(clean_claims)

        sitelinks = WikidataLabels._remove_keys(item.get('sitelinks', {}), ['badges'])

        data_batch.put({
            'id': item['id'],
            'labels': item['labels'],
            'descriptions': item['descriptions'],
            'aliases': item['aliases'],
            'sitelinks': sitelinks,
            'claims': clean_claims
        })

def writer_loop(data_batch, finished):
    file_handle = None
    NUM_ITEMS = 0
    FILE_ID = 0
    FILE_SIZE = 1_000_000

    while True:
        if finished.value == 1 and data_batch.empty():
            if file_handle is not None:
                file_handle.write('\n]')
                file_handle.close()
            break

        try:
            next_item = data_batch.get(timeout=1)
        except:
            continue

        if next_item:

            if file_handle is None:
                file_handle = gzip.open(f'chunk_{FILE_ID}.json.gz', mode='wt')
                file_handle.write('[\n')
                NUM_ITEMS = 0

            json_data = json.dumps(next_item, separators=(',', ':'))
            file_handle.write(json_data)
            NUM_ITEMS += 1

            if NUM_ITEMS >= FILE_SIZE:
                file_handle.write('\n]')
                file_handle.close()
                file_handle = None
                FILE_ID += 1
                NUM_ITEMS = 0
            else:
                file_handle.write(",\n")

data_batch = Queue(maxsize=QUEUE_SIZE)
finished = Value('i', 0)
with finished.get_lock():
    finished.value = 0

wikidata = WikidataDumpReader(FILEPATH, num_processes=NUM_PROCESSES, queue_size=QUEUE_SIZE, skiplines=SKIPLINES)

writer_process = Process(
    target=writer_loop,
    args=(data_batch, finished)
)
writer_process.start()

wikidata.run(lambda item: save_to_queue(item, data_batch), max_iterations=None, verbose=True)

with finished.get_lock():
    finished.value = 1

writer_process.join()
# Out:
# Skipping lines: 0it [00:00, ?it/s]
# Items Processed: 2797 | Processing Rate: 932 items/sec | Memory Usage: 139.02 MB
# Items Processed: 4748 | Processing Rate: 791 items/sec | Memory Usage: 141.83 MB
# Items Processed: 6900 | Processing Rate: 766 items/sec | Memory Usage: 141.83 MB
# Items Processed: 8933 | Processing Rate: 744 items/sec | Memory Usage: 141.83 MB
# Items Processed: 11352 | Processing Rate: 756 items/sec | Memory Usage: 141.83 MB
# Items Processed: 14479 | Processing Rate: 804 items/sec | Memory Usage: 141.83 MB
# Items Processed: 17517 | Processing Rate: 834 items/sec | Memory Usage: 141.83 MB
# Items Processed: 19807 | Processing Rate: 825 items/sec | Memory Usage: 141.83 MB
# Items Processed: 21979 | Processing Rate: 814 items/sec | Memory Usage: 141.83 MB
# Items Processed: 24263 | Processing Rate: 808 items/sec | Memory Usage: 141.83 MB
# Items Processed: 26417 | Processing Rate: 800 items/sec | Memory Usage: 141.83 MB
# Items Processed: 28877 | Processing Rate: 802 items/sec | Memory Usage: 141.83 MB
# Items Processed: 31568 | Processing Rate: 809 items/sec | Memory Usage: 141.83 MB
# Items Processed: 33995 | Processing Rate: 809 items/sec | Memory Usage: 141.83 MB
# Items Processed: 37098 | Processing Rate: 824 items/sec | Memory Usage: 141.83 MB
# Items Processed: 39996 | Processing Rate: 833 items/sec | Memory Usage: 141.83 MB
# Items Processed: 43339 | Processing Rate: 849 items/sec | Memory Usage: 141.83 MB
# Items Processed: 46762 | Processing Rate: 865 items/sec | Memory Usage: 141.83 MB
# Items Processed: 50174 | Processing Rate: 880 items/sec | Memory Usage: 141.83 MB
# Items Processed: 53529 | Processing Rate: 892 items/sec | Memory Usage: 141.83 MB
# Items Processed: 56703 | Processing Rate: 900 items/sec | Memory Usage: 141.83 MB
# Items Processed: 59932 | Processing Rate: 908 items/sec | Memory Usage: 141.83 MB
# Items Processed: 63196 | Processing Rate: 915 items/sec | Memory Usage: 141.83 MB
# Items Processed: 66689 | Processing Rate: 926 items/sec | Memory Usage: 141.83 MB
# Items Processed: 70750 | Processing Rate: 943 items/sec | Memory Usage: 141.83 MB
# Items Processed: 74603 | Processing Rate: 956 items/sec | Memory Usage: 141.83 MB
# Items Processed: 78526 | Processing Rate: 969 items/sec | Memory Usage: 141.83 MB
# Items Processed: 82141 | Processing Rate: 977 items/sec | Memory Usage: 141.83 MB
# Items Processed: 85788 | Processing Rate: 986 items/sec | Memory Usage: 141.83 MB
# Items Processed: 90077 | Processing Rate: 1000 items/sec | Memory Usage: 141.83 MB
# Items Processed: 95700 | Processing Rate: 1028 items/sec | Memory Usage: 141.83 MB
# Items Processed: 100333 | Processing Rate: 1045 items/sec | Memory Usage: 141.83 MB
# Items Processed: 105449 | Processing Rate: 1065 items/sec | Memory Usage: 141.83 MB
# Items Processed: 109730 | Processing Rate: 1075 items/sec | Memory Usage: 141.83 MB
# Items Processed: 113832 | Processing Rate: 1083 items/sec | Memory Usage: 141.83 MB
# Items Processed: 118917 | Processing Rate: 1100 items/sec | Memory Usage: 141.83 MB
# Items Processed: 123905 | Processing Rate: 1116 items/sec | Memory Usage: 141.83 MB
# Items Processed: 127733 | Processing Rate: 1120 items/sec | Memory Usage: 141.83 MB
# Items Processed: 132523 | Processing Rate: 1132 items/sec | Memory Usage: 141.83 MB
# Items Processed: 137580 | Processing Rate: 1146 items/sec | Memory Usage: 141.83 MB
# Items Processed: 142994 | Processing Rate: 1162 items/sec | Memory Usage: 141.83 MB
# Items Processed: 148363 | Processing Rate: 1177 items/sec | Memory Usage: 141.83 MB
# Items Processed: 154391 | Processing Rate: 1196 items/sec | Memory Usage: 141.83 MB
# Items Processed: 159479 | Processing Rate: 1207 items/sec | Memory Usage: 141.83 MB
# Items Processed: 164977 | Processing Rate: 1221 items/sec | Memory Usage: 141.83 MB
# Items Processed: 170968 | Processing Rate: 1238 items/sec | Memory Usage: 141.83 MB
# Items Processed: 176930 | Processing Rate: 1254 items/sec | Memory Usage: 141.83 MB
# Items Processed: 183715 | Processing Rate: 1275 items/sec | Memory Usage: 141.83 MB
# Items Processed: 189707 | Processing Rate: 1290 items/sec | Memory Usage: 141.83 MB
# Items Processed: 195486 | Processing Rate: 1302 items/sec | Memory Usage: 141.83 MB
# Items Processed: 202356 | Processing Rate: 1322 items/sec | Memory Usage: 141.83 MB
# Items Processed: 208879 | Processing Rate: 1338 items/sec | Memory Usage: 141.83 MB
# Items Processed: 216477 | Processing Rate: 1361 items/sec | Memory Usage: 141.83 MB
# Items Processed: 223933 | Processing Rate: 1381 items/sec | Memory Usage: 141.83 MB
# Items Processed: 231053 | Processing Rate: 1400 items/sec | Memory Usage: 141.83 MB
# Items Processed: 237674 | Processing Rate: 1414 items/sec | Memory Usage: 141.83 MB
# Items Processed: 244377 | Processing Rate: 1428 items/sec | Memory Usage: 141.83 MB
# Items Processed: 252495 | Processing Rate: 1450 items/sec | Memory Usage: 141.83 MB
# Items Processed: 260516 | Processing Rate: 1471 items/sec | Memory Usage: 141.83 MB
# Items Processed: 268651 | Processing Rate: 1492 items/sec | Memory Usage: 141.83 MB
# Items Processed: 276650 | Processing Rate: 1511 items/sec | Memory Usage: 141.83 MB
# Items Processed: 284227 | Processing Rate: 1527 items/sec | Memory Usage: 141.83 MB
# Items Processed: 291945 | Processing Rate: 1544 items/sec | Memory Usage: 141.83 MB
# Items Processed: 299687 | Processing Rate: 1560 items/sec | Memory Usage: 141.83 MB
# Items Processed: 306273 | Processing Rate: 1570 items/sec | Memory Usage: 141.83 MB
# Items Processed: 313156 | Processing Rate: 1581 items/sec | Memory Usage: 141.83 MB
# Items Processed: 320750 | Processing Rate: 1595 items/sec | Memory Usage: 141.83 MB
# Items Processed: 330627 | Processing Rate: 1620 items/sec | Memory Usage: 141.83 MB
# Items Processed: 339023 | Processing Rate: 1637 items/sec | Memory Usage: 141.83 MB
# Items Processed: 348109 | Processing Rate: 1657 items/sec | Memory Usage: 141.83 MB
# Items Processed: 356649 | Processing Rate: 1673 items/sec | Memory Usage: 141.83 MB
# Items Processed: 364502 | Processing Rate: 1687 items/sec | Memory Usage: 141.83 MB
# Items Processed: 372190 | Processing Rate: 1699 items/sec | Memory Usage: 141.83 MB
# Items Processed: 380325 | Processing Rate: 1712 items/sec | Memory Usage: 141.83 MB
# Items Processed: 388162 | Processing Rate: 1724 items/sec | Memory Usage: 141.83 MB
# Items Processed: 397276 | Processing Rate: 1741 items/sec | Memory Usage: 141.83 MB
# Items Processed: 405892 | Processing Rate: 1756 items/sec | Memory Usage: 141.83 MB
# Items Processed: 414158 | Processing Rate: 1769 items/sec | Memory Usage: 141.83 MB
# Items Processed: 423565 | Processing Rate: 1786 items/sec | Memory Usage: 141.83 MB
# Items Processed: 432159 | Processing Rate: 1800 items/sec | Memory Usage: 141.83 MB
# Items Processed: 441065 | Processing Rate: 1814 items/sec | Memory Usage: 141.83 MB
# Items Processed: 451548 | Processing Rate: 1835 items/sec | Memory Usage: 141.83 MB
# Items Processed: 461342 | Processing Rate: 1852 items/sec | Memory Usage: 141.83 MB
# Items Processed: 468276 | Processing Rate: 1857 items/sec | Memory Usage: 141.83 MB
# Items Processed: 475522 | Processing Rate: 1864 items/sec | Memory Usage: 141.83 MB
# Items Processed: 482484 | Processing Rate: 1869 items/sec | Memory Usage: 141.83 MB
# Items Processed: 489738 | Processing Rate: 1875 items/sec | Memory Usage: 141.83 MB
# Items Processed: 496899 | Processing Rate: 1881 items/sec | Memory Usage: 141.83 MB
# Items Processed: 504060 | Processing Rate: 1887 items/sec | Memory Usage: 141.83 MB
# Items Processed: 511260 | Processing Rate: 1892 items/sec | Memory Usage: 141.83 MB
# Items Processed: 523442 | Processing Rate: 1916 items/sec | Memory Usage: 141.83 MB
# Items Processed: 533450 | Processing Rate: 1932 items/sec | Memory Usage: 141.83 MB
# Items Processed: 543027 | Processing Rate: 1945 items/sec | Memory Usage: 141.83 MB
# Items Processed: 553450 | Processing Rate: 1961 items/sec | Memory Usage: 141.83 MB
# Items Processed: 563043 | Processing Rate: 1974 items/sec | Memory Usage: 141.83 MB
# Items Processed: 572715 | Processing Rate: 1987 items/sec | Memory Usage: 141.83 MB
# Items Processed: 582934 | Processing Rate: 2002 items/sec | Memory Usage: 141.83 MB
# Items Processed: 592172 | Processing Rate: 2013 items/sec | Memory Usage: 141.83 MB
# Items Processed: 602005 | Processing Rate: 2026 items/sec | Memory Usage: 141.83 MB
# Items Processed: 612446 | Processing Rate: 2040 items/sec | Memory Usage: 141.83 MB
# Items Processed: 621869 | Processing Rate: 2051 items/sec | Memory Usage: 141.83 MB
# Items Processed: 630382 | Processing Rate: 2059 items/sec | Memory Usage: 141.83 MB
# Items Processed: 640777 | Processing Rate: 2073 items/sec | Memory Usage: 141.83 MB
# Items Processed: 926443 | Processing Rate: 2220 items/sec | Memory Usage: 141.83 MB
# Items Processed: 935771 | Processing Rate: 2227 items/sec | Memory Usage: 141.83 MB
# Items Processed: 945628 | Processing Rate: 2234 items/sec | Memory Usage: 141.83 MB
# Items Processed: 955976 | Processing Rate: 2243 items/sec | Memory Usage: 141.83 MB
# Items Processed: 966495 | Processing Rate: 2252 items/sec | Memory Usage: 141.83 MB
# Items Processed: 976044 | Processing Rate: 2258 items/sec | Memory Usage: 141.83 MB
# Items Processed: 987122 | Processing Rate: 2268 items/sec | Memory Usage: 141.83 MB
# Items Processed: 997186 | Processing Rate: 2275 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1006495 | Processing Rate: 2281 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1018112 | Processing Rate: 2292 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1029242 | Processing Rate: 2301 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1042629 | Processing Rate: 2316 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1055989 | Processing Rate: 2330 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1070311 | Processing Rate: 2346 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1084427 | Processing Rate: 2361 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1097743 | Processing Rate: 2375 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1111038 | Processing Rate: 2388 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1122366 | Processing Rate: 2397 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1134262 | Processing Rate: 2407 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1145569 | Processing Rate: 2415 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1154209 | Processing Rate: 2418 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1162599 | Processing Rate: 2421 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1171006 | Processing Rate: 2423 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1184198 | Processing Rate: 2435 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1200362 | Processing Rate: 2453 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1216075 | Processing Rate: 2470 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1230702 | Processing Rate: 2485 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1242308 | Processing Rate: 2493 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1256463 | Processing Rate: 2507 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1265891 | Processing Rate: 2510 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1275833 | Processing Rate: 2515 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1288911 | Processing Rate: 2526 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1304646 | Processing Rate: 2542 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1323377 | Processing Rate: 2563 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1337384 | Processing Rate: 2575 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1354705 | Processing Rate: 2594 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1370466 | Processing Rate: 2609 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1380316 | Processing Rate: 2613 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1388193 | Processing Rate: 2613 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1398891 | Processing Rate: 2618 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1409110 | Processing Rate: 2623 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1429920 | Processing Rate: 2647 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1447116 | Processing Rate: 2664 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1465969 | Processing Rate: 2683 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1487912 | Processing Rate: 2709 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1495602 | Processing Rate: 2708 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1501170 | Processing Rate: 2703 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1507746 | Processing Rate: 2701 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1516820 | Processing Rate: 2702 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1530202 | Processing Rate: 2712 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1546751 | Processing Rate: 2726 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1558213 | Processing Rate: 2732 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1567831 | Processing Rate: 2735 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1575585 | Processing Rate: 2734 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1582578 | Processing Rate: 2732 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1586014 | Processing Rate: 2724 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1591251 | Processing Rate: 2719 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1598429 | Processing Rate: 2717 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1606299 | Processing Rate: 2716 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1614305 | Processing Rate: 2716 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1623689 | Processing Rate: 2718 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1633873 | Processing Rate: 2722 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1644743 | Processing Rate: 2726 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1655590 | Processing Rate: 2731 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1666985 | Processing Rate: 2736 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1676744 | Processing Rate: 2738 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1689417 | Processing Rate: 2746 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1698931 | Processing Rate: 2748 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1713892 | Processing Rate: 2758 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1727732 | Processing Rate: 2767 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1737624 | Processing Rate: 2770 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1746108 | Processing Rate: 2770 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1753209 | Processing Rate: 2768 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1768033 | Processing Rate: 2778 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1781480 | Processing Rate: 2786 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1793799 | Processing Rate: 2793 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1804699 | Processing Rate: 2796 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1817953 | Processing Rate: 2804 items/sec | Memory Usage: 141.83 MB
# Items Processed: 1833013 | Processing Rate: 2814 items/sec | Memory Usage: 141.83 MB
# Items Processed: 
# Items Processed: 111964486 | Processing Rate: 2802 items/sec | Memory Usage: 141.83 MB
# Items Processed: 111981920 | Processing Rate: 2802 items/sec | Memory Usage: 141.83 MB
# Items Processed: 112002122 | Processing Rate: 2802 items/sec | Memory Usage: 141.83 MB
# Items Processed: 112025557 | Processing Rate: 2803 items/sec | Memory Usage: 141.83 MB
# Items Processed: 112046888 | Processing Rate: 2803 items/sec | Memory Usage: 141.83 MB
# Items Processed: 112069721 | Processing Rate: 2803 items/sec | Memory Usage: 141.83 MB
# Items Processed: 112089776 | Processing Rate: 2804 items/sec | Memory Usage: 141.83 MB
# Items Processed: 112109152 | Processing Rate: 2804 items/sec | Memory Usage: 141.83 MB
# Items Processed: 112130714 | Processing Rate: 2804 items/sec | Memory Usage: 141.83 MB
# Items Processed: 112153891 | Processing Rate: 2805 items/sec | Memory Usage: 141.83 MB
# Items Processed: 112180334 | Processing Rate: 2805 items/sec | Memory Usage: 141.83 MB
# Items Processed: 112200816 | Processing Rate: 2805 items/sec | Memory Usage: 141.83 MB
# Items Processed: 112219347 | Processing Rate: 2806 items/sec | Memory Usage: 141.83 MB
# Items Processed: 112238759 | Processing Rate: 2806 items/sec | Memory Usage: 141.83 MB
# Items Processed: 112257833 | Processing Rate: 2806 items/sec | Memory Usage: 141.83 MB
# Items Processed: 112279384 | Processing Rate: 2807 items/sec | Memory Usage: 141.83 MB
# Items Processed: 112299054 | Processing Rate: 2807 items/sec | Memory Usage: 141.83 MB
# Items Processed: 112316984 | Processing Rate: 2807 items/sec | Memory Usage: 141.83 MB
# Items Processed: 112334998 | Processing Rate: 2807 items/sec | Memory Usage: 141.83 MB
# Items Processed: 112357813 | Processing Rate: 2808 items/sec | Memory Usage: 141.83 MB
# Items Processed: 112380290 | Processing Rate: 2808 items/sec | Memory Usage: 141.83 MB
# Items Processed: 112397895 | Processing Rate: 2808 items/sec | Memory Usage: 141.83 MB
# Items Processed: 112415476 | Processing Rate: 2808 items/sec | Memory Usage: 141.83 MB
# Items Processed: 112432995 | Processing Rate: 2809 items/sec | Memory Usage: 141.83 MB
# Items Processed: 112451493 | Processing Rate: 2809 items/sec | Memory Usage: 141.83 MB
# Items Processed: 112467854 | Processing Rate: 2809 items/sec | Memory Usage: 141.83 MB

# %%
import gzip
import json
import sys
sys.path.append('../src')

from wikidata_dumpreader import WikidataDumpReader
from wikidataLabelsDB import WikidataLabels
from multiprocessing import Process, Value, Queue
import os

QUEUE_SIZE = int(os.getenv("QUEUE_SIZE", 5000))
NUM_PROCESSES = int(os.getenv("NUM_PROCESSES", 2))
SKIPLINES = 0

def save_to_queue(item, data_batch):
    if (item is not None):
        claims = WikidataLabels.add_labels_batched(item['claims'], query_batch=100)
        data_batch.put({
            'id': item['id'],
            'labels': item['labels'],
            'descriptions': item['descriptions'],
            'aliases': item['aliases'],
            'sitelinks': item['sitelinks'],
            'claims': claims
        })

def writer_loop(data_batch, finished, filename):
    file_handle = gzip.open(filename, mode='wt')
    file_handle.write('[\n')

    while True:
        if finished.value == 1 and data_batch.empty():
            if file_handle is not None:
                file_handle.write('\n]')
                file_handle.close()
            break

        try:
            next_item = data_batch.get(timeout=1)
        except:
            continue

        if next_item:
            json_data = json.dumps(next_item, separators=(',', ':'))
            file_handle.write(json_data)
            file_handle.write(",\n")

for i in range(112):
    FILEPATH = f"../data/Wikidata/latest-all-chunks/chunk_{i}.json.gz"
    filename = f"../data/Wikidata/latest-all-chunks/clean_chunk_{i}.json.gz"

    data_batch = Queue(maxsize=QUEUE_SIZE)
    finished = Value('i', 0)
    with finished.get_lock():
        finished.value = 0

    wikidata = WikidataDumpReader(FILEPATH, num_processes=NUM_PROCESSES, queue_size=QUEUE_SIZE, skiplines=SKIPLINES)

    writer_process = Process(
        target=writer_loop,
        args=(data_batch, finished, filename)
    )
    writer_process.start()

    wikidata.run(lambda item: save_to_queue(item, data_batch), max_iterations=None, verbose=True)

    with finished.get_lock():
        finished.value = 1

    writer_process.join()

    # data = Dataset.from_json(filename, split=f'chunk_{i}')
    # data.push_to_hub("wikidata")
    # os.remove(filename)
# Out:
# Skipping lines: 0it [00:00, ?it/s]
# Items Processed: 325 | Processing Rate: 108 items/sec
# Items Processed: 1084 | Processing Rate: 181 items/sec
# Items Processed: 1730 | Processing Rate: 192 items/sec
# Items Processed: 2563 | Processing Rate: 213 items/sec
# Items Processed: 3405 | Processing Rate: 227 items/sec
# Items Processed: 4531 | Processing Rate: 252 items/sec
# Items Processed: 5025 | Processing Rate: 239 items/sec
# Items Processed: 5029 | Processing Rate: 209 items/sec
# Items Processed: 5032 | Processing Rate: 186 items/sec
# Items Processed: 5032 | Processing Rate: 168 items/sec
# Items Processed: 5032 | Processing Rate: 152 items/sec
# Items Processed: 5032 | Processing Rate: 140 items/sec
# Items Processed: 5032 | Processing Rate: 129 items/sec
# Items Processed: 5037 | Processing Rate: 120 items/sec
# Items Processed: 5042 | Processing Rate: 112 items/sec
# Items Processed: 5045 | Processing Rate: 105 items/sec
# Items Processed: 5050 | Processing Rate: 99 items/sec
# Items Processed: 5058 | Processing Rate: 94 items/sec
# Items Processed: 5064 | Processing Rate: 89 items/sec
# Items Processed: 5070 | Processing Rate: 84 items/sec
# Items Processed: 5076 | Processing Rate: 81 items/sec
# Items Processed: 5087 | Processing Rate: 77 items/sec
# Items Processed: 5091 | Processing Rate: 74 items/sec
# Items Processed: 5096 | Processing Rate: 71 items/sec
# Items Processed: 5101 | Processing Rate: 68 items/sec
# Items Processed: 5106 | Processing Rate: 65 items/sec
# Items Processed: 5114 | Processing Rate: 63 items/sec
# Items Processed: 5119 | Processing Rate: 61 items/sec
# Items Processed: 5123 | Processing Rate: 59 items/sec
# Items Processed: 5129 | Processing Rate: 57 items/sec
# Items Processed: 5135 | Processing Rate: 55 items/sec
# Items Processed: 5144 | Processing Rate: 54 items/sec
# Items Processed: 5150 | Processing Rate: 52 items/sec
# Items Processed: 5161 | Processing Rate: 51 items/sec
# Items Processed: 5172 | Processing Rate: 49 items/sec
# Items Processed: 5182 | Processing Rate: 48 items/sec
# Items Processed: 5187 | Processing Rate: 47 items/sec
# Items Processed: 5192 | Processing Rate: 46 items/sec
# Items Processed: 5204 | Processing Rate: 44 items/sec
# Items Processed: 5214 | Processing Rate: 43 items/sec
# Items Processed: 5220 | Processing Rate: 42 items/sec
# Items Processed: 5237 | Processing Rate: 42 items/sec
# Items Processed: 5248 | Processing Rate: 41 items/sec
# Items Processed: 5256 | Processing Rate: 40 items/sec
# Items Processed: 5268 | Processing Rate: 39 items/sec
# Items Processed: 5276 | Processing Rate: 38 items/sec
# Items Processed: 5291 | Processing Rate: 38 items/sec
# Items Processed: 5302 | Processing Rate: 37 items/sec
# Items Processed: 5313 | Processing Rate: 36 items/sec
# Items Processed: 5326 | Processing Rate: 35 items/sec
# Items Processed: 5337 | Processing Rate: 35 items/sec
# Items Processed: 5346 | Processing Rate: 34 items/sec
# Items Processed: 5358 | Processing Rate: 34 items/sec
# Items Processed: 5375 | Processing Rate: 33 items/sec
# Items Processed: 5393 | Processing Rate: 33 items/sec
# Items Processed: 5407 | Processing Rate: 32 items/sec
# Items Processed: 5420 | Processing Rate: 32 items/sec
# Items Processed: 5436 | Processing Rate: 31 items/sec
# Items Processed: 5457 | Processing Rate: 31 items/sec
# Items Processed: 5483 | Processing Rate: 30 items/sec
# Items Processed: 5510 | Processing Rate: 30 items/sec
# Items Processed: 5530 | Processing Rate: 30 items/sec
# Items Processed: 5540 | Processing Rate: 29 items/sec
# Items Processed: 5559 | Processing Rate: 29 items/sec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 66
#      60 writer_process = Process(
#      61     target=writer_loop,
#      62     args=(data_batch, finished, filename)
#      63 )
#      64 writer_process.start()
# ---> 66 wikidata.run(lambda item: save_to_queue(item, data_batch), max_iterations=None, verbose=True)
#      68 with finished.get_lock():
#      69     finished.value = 1
#
# File ~/GitHub/WikidataTextEmbedding/notebooks/../src/wikidata_dumpreader.py:90, in WikidataDumpReader.run(self, handler_func, max_iterations, verbose)
#      87     reporter_p.start()
#      89 # Wait for processes to finish
# ---> 90 producer_p.join()
#      91 for cp in consumer_ps:
#      92     cp.join()
#
# File ~/anaconda3/lib/python3.12/multiprocessing/process.py:149, in BaseProcess.join(self, timeout)
#     147 assert self._parent_pid == os.getpid(), 'can only join a child process'
#     148 assert self._popen is not None, 'can only join a started process'
# --> 149 res = self._popen.wait(timeout)
#     150 if res is not None:
#     151     _children.discard(self)
#
# File ~/anaconda3/lib/python3.12/multiprocessing/popen_fork.py:43, in Popen.wait(self, timeout)
#      41             return None
#      42     # This shouldn't block if wait() returned successfully.
# ---> 43     return self.poll(os.WNOHANG if timeout == 0.0 else 0)
#      44 return self.returncode
#
# File ~/anaconda3/lib/python3.12/multiprocessing/popen_fork.py:27, in Popen.poll(self, flag)
#      25 if self.returncode is None:
#      26     try:
# ---> 27         pid, sts = os.waitpid(self.pid, flag)
#      28     except OSError:
#      29         # Child process not yet created. See #1731717
#      30         # e.errno == errno.ECHILD == 10
#      31         return None
#
# KeyboardInterrupt:
# Items Processed: 5579 | Processing Rate: 29 items/sec
# Items Processed: 5593 | Processing Rate: 28 items/sec
# Items Processed: 5613 | Processing Rate: 28 items/sec
# Items Processed: 5627 | Processing Rate: 28 items/sec
# Items Processed: 5652 | Processing Rate: 27 items/sec
# Items Processed: 5662 | Processing Rate: 27 items/sec
# Items Processed: 5676 | Processing Rate: 27 items/sec
# Items Processed: 5695 | Processing Rate: 26 items/sec
# Items Processed: 5714 | Processing Rate: 26 items/sec
# Items Processed: 5725 | Processing Rate: 26 items/sec
# Items Processed: 5743 | Processing Rate: 26 items/sec
# Items Processed: 5759 | Processing Rate: 25 items/sec
# Items Processed: 5766 | Processing Rate: 25 items/sec
# Items Processed: 5780 | Processing Rate: 25 items/sec
# Items Processed: 5800 | Processing Rate: 24 items/sec
# Items Processed: 5816 | Processing Rate: 24 items/sec
# Items Processed: 5832 | Processing Rate: 24 items/sec
# Items Processed: 5847 | Processing Rate: 24 items/sec
# Items Processed: 5864 | Processing Rate: 24 items/sec
# Items Processed: 5880 | Processing Rate: 23 items/sec
# Items Processed: 5895 | Processing Rate: 23 items/sec
# Items Processed: 5911 | Processing Rate: 23 items/sec
# Items Processed: 5922 | Processing Rate: 23 items/sec
# Items Processed: 5942 | Processing Rate: 22 items/sec
# Items Processed: 5954 | Processing Rate: 22 items/sec
# Items Processed: 5970 | Processing Rate: 22 items/sec
# Items Processed: 5983 | Processing Rate: 22 items/sec
# Items Processed: 5986 | Processing Rate: 22 items/sec
# Items Processed: 5997 | Processing Rate: 21 items/sec
# Items Processed: 6012 | Processing Rate: 21 items/sec
# Items Processed: 6023 | Processing Rate: 21 items/sec
# Items Processed: 6043 | Processing Rate: 21 items/sec
# Items Processed: 6054 | Processing Rate: 21 items/sec
# Items Processed: 6067 | Processing Rate: 21 items/sec
# Items Processed: 6077 | Processing Rate: 20 items/sec
# Items Processed: 6090 | Processing Rate: 20 items/sec
# Items Processed: 6103 | Processing Rate: 20 items/sec
# Items Processed: 6116 | Processing Rate: 20 items/sec
# Items Processed: 6127 | Processing Rate: 20 items/sec
# Items Processed: 6143 | Processing Rate: 20 items/sec
# Items Processed: 6159 | Processing Rate: 20 items/sec
# Items Processed: 6170 | Processing Rate: 19 items/sec
# Items Processed: 6183 | Processing Rate: 19 items/sec
# Items Processed: 6193 | Processing Rate: 19 items/sec
# Items Processed: 6207 | Processing Rate: 19 items/sec
# Items Processed: 6223 | Processing Rate: 19 items/sec
# Items Processed: 6236 | Processing Rate: 19 items/sec
# Items Processed: 6255 | Processing Rate: 19 items/sec
# Items Processed: 6272 | Processing Rate: 18 items/sec
# Items Processed: 6285 | Processing Rate: 18 items/sec
# Items Processed: 6305 | Processing Rate: 18 items/sec
# Items Processed: 6321 | Processing Rate: 18 items/sec
# Items Processed: 6346 | Processing Rate: 18 items/sec
# Items Processed: 6363 | Processing Rate: 18 items/sec
# Items Processed: 6380 | Processing Rate: 18 items/sec
# Items Processed: 6396 | Processing Rate: 18 items/sec
# Items Processed: 6403 | Processing Rate: 18 items/sec
# Items Processed: 6409 | Processing Rate: 17 items/sec
# Items Processed: 6420 | Processing Rate: 17 items/sec
# Items Processed: 6433 | Processing Rate: 17 items/sec
# Items Processed: 6448 | Processing Rate: 17 items/sec
# Items Processed: 6459 | Processing Rate: 17 items/sec
# Items Processed: 6470 | Processing Rate: 17 items/sec
# Items Processed: 6482 | Processing Rate: 17 items/sec
# Items Processed: 6494 | Processing Rate: 17 items/sec
# Items Processed: 6502 | Processing Rate: 17 items/sec
# Items Processed: 6517 | Processing Rate: 17 items/sec
# Items Processed: 6529 | Processing Rate: 16 items/sec
# Items Processed: 6541 | Processing Rate: 16 items/sec
# Items Processed: 6555 | Processing Rate: 16 items/sec
# Items Processed: 6568 | Processing Rate: 16 items/sec
# Items Processed: 6583 | Processing Rate: 16 items/sec
# Items Processed: 6598 | Processing Rate: 16 items/sec
# Items Processed: 6607 | Processing Rate: 16 items/sec
# Items Processed: 6621 | Processing Rate: 16 items/sec
# Items Processed: 6631 | Processing Rate: 16 items/sec
# Items Processed: 6644 | Processing Rate: 16 items/sec
# Items Processed: 6652 | Processing Rate: 16 items/sec
# Items Processed: 6667 | Processing Rate: 16 items/sec
# Items Processed: 6679 | Processing Rate: 15 items/sec
# Items Processed: 6694 | Processing Rate: 15 items/sec
# Items Processed: 6709 | Processing Rate: 15 items/sec
# Items Processed: 6721 | Processing Rate: 15 items/sec
# Items Processed: 6737 | Processing Rate: 15 items/sec
# Items Processed: 6755 | Processing Rate: 15 items/sec
# Items Processed: 6775 | Processing Rate: 15 items/sec
# Items Processed: 6789 | Processing Rate: 15 items/sec
# Items Processed: 6804 | Processing Rate: 15 items/sec
# Items Processed: 6823 | Processing Rate: 15 items/sec
# Items Processed: 6839 | Processing Rate: 15 items/sec
# Items Processed: 6849 | Processing Rate: 15 items/sec
# Items Processed: 6864 | Processing Rate: 15 items/sec
# Items Processed: 6873 | Processing Rate: 15 items/sec
# Items Processed: 6880 | Processing Rate: 15 items/sec
# Items Processed: 6891 | Processing Rate: 14 items/sec
# Items Processed: 6908 | Processing Rate: 14 items/sec
# Items Processed: 6923 | Processing Rate: 14 items/sec
# Items Processed: 6940 | Processing Rate: 14 items/sec
# Items Processed: 6949 | Processing Rate: 14 items/sec
# Items Processed: 6967 | Processing Rate: 14 items/sec
# Items Processed: 6981 | Processing Rate: 14 items/sec
# Items Processed: 6997 | Processing Rate: 14 items/sec
# Items Processed: 7009 | Processing Rate: 14 items/sec
# Items Processed: 7027 | Processing Rate: 14 items/sec
# Items Processed: 7037 | Processing Rate: 14 items/sec
# Items Processed: 7055 | Processing Rate: 14 items/sec
# Items Processed: 7072 | Processing Rate: 14 items/sec
# Items Processed: 7090 | Processing Rate: 14 items/sec
# Items Processed: 7102 | Processing Rate: 14 items/sec
# Items Processed: 7124 | Processing Rate: 14 items/sec
# Items Processed: 7146 | Processing Rate: 14 items/sec
# Items Processed: 7167 | Processing Rate: 14 items/sec
# Items Processed: 7189 | Processing Rate: 14 items/sec
# Items Processed: 8162 | Processing Rate: 12 items/sec
# Items Processed: 8175 | Processing Rate: 12 items/sec
# Items Processed: 8202 | Processing Rate: 12 items/sec
# Items Processed: 8224 | Processing Rate: 12 items/sec
# Items Processed: 8242 | Processing Rate: 11 items/sec
# Items Processed: 8257 | Processing Rate: 11 items/sec
# Items Processed: 8271 | Processing Rate: 11 items/sec
# Items Processed: 8295 | Processing Rate: 11 items/sec
# Items Processed: 8309 | Processing Rate: 11 items/sec
# Items Processed: 8331 | Processing Rate: 11 items/sec
# Items Processed: 8359 | Processing Rate: 11 items/sec
# Items Processed: 8382 | Processing Rate: 11 items/sec
# Items Processed: 8395 | Processing Rate: 11 items/sec
# Items Processed: 8416 | Processing Rate: 11 items/sec
# Items Processed: 8437 | Processing Rate: 11 items/sec
# Items Processed: 8457 | Processing Rate: 11 items/sec
# Items Processed: 8480 | Processing Rate: 11 items/sec
# Items Processed: 8507 | Processing Rate: 11 items/sec
# Items Processed: 8532 | Processing Rate: 11 items/sec
# Items Processed: 8547 | Processing Rate: 11 items/sec
# Items Processed: 8572 | Processing Rate: 11 items/sec
# Items Processed: 8596 | Processing Rate: 11 items/sec
# Items Processed: 8615 | Processing Rate: 11 items/sec
# Items Processed: 8646 | Processing Rate: 11 items/sec
# Items Processed: 8679 | Processing Rate: 11 items/sec
# Items Processed: 8700 | Processing Rate: 11 items/sec
# Items Processed: 8721 | Processing Rate: 11 items/sec
# Items Processed: 8745 | Processing Rate: 11 items/sec
# Items Processed: 8776 | Processing Rate: 11 items/sec
# Items Processed: 8797 | Processing Rate: 11 items/sec
# Items Processed: 8830 | Processing Rate: 11 items/sec
# Items Processed: 8847 | Processing Rate: 11 items/sec
# Items Processed: 8866 | Processing Rate: 11 items/sec
# Items Processed: 8884 | Processing Rate: 11 items/sec
# Items Processed: 8913 | Processing Rate: 11 items/sec
# Items Processed: 8932 | Processing Rate: 11 items/sec
# Items Processed: 8963 | Processing Rate: 11 items/sec
# Items Processed: 8984 | Processing Rate: 11 items/sec
# Items Processed: 9010 | Processing Rate: 11 items/sec
# Items Processed: 9028 | Processing Rate: 11 items/sec
# Items Processed: 9051 | Processing Rate: 11 items/sec
# Items Processed: 9071 | Processing Rate: 11 items/sec
# Items Processed: 9092 | Processing Rate: 11 items/sec
# Items Processed: 9112 | Processing Rate: 11 items/sec
# Items Processed: 9133 | Processing Rate: 11 items/sec
# Items Processed: 9155 | Processing Rate: 11 items/sec
# Items Processed: 9168 | Processing Rate: 11 items/sec
# Items Processed: 9187 | Processing Rate: 11 items/sec
# Items Processed: 9203 | Processing Rate: 11 items/sec
# Items Processed: 9231 | Processing Rate: 11 items/sec
# Items Processed: 9248 | Processing Rate: 11 items/sec
# Items Processed: 9273 | Processing Rate: 11 items/sec
# Items Processed: 9297 | Processing Rate: 11 items/sec
# Items Processed: 9320 | Processing Rate: 11 items/sec
# Items Processed: 9337 | Processing Rate: 11 items/sec

# %%
import os
import json
import sys
from multiprocessing import Process, Value, Queue
sys.path.append('../src')

from wikidata_dumpreader import WikidataDumpReader
from wikidataLabelsDB import WikidataLabels

from datasets import Dataset

# Constants
QUEUE_SIZE = int(os.getenv("QUEUE_SIZE", 5000))
NUM_PROCESSES = int(os.getenv("NUM_PROCESSES", 2))
SKIPLINES = 0

def save_to_queue(item, data_queue):
    """Processes and puts cleaned item into the multiprocessing queue."""
    if item is not None:
        claims = WikidataLabels.add_labels_batched(item['claims'], query_batch=100)
        data_queue.put({
            'id': item['id'],
            'labels': json.dumps(item['labels'], separators=(',', ':')),
            'descriptions': json.dumps(item['descriptions'], separators=(',', ':')),
            'aliases': json.dumps(item['aliases'], separators=(',', ':')),
            'sitelinks': json.dumps(item['sitelinks'], separators=(',', ':')),
            'claims': json.dumps(claims, separators=(',', ':'))
        })

def chunk_generator(filepath, num_processes=2, queue_size=5000, skip_lines=0):
    """
    A generator function that reads a chunk file with WikidataDumpReader,
    processes each item, and yields the result. It uses a multiprocessing
    queue to handle data ingestion in parallel without storing everything
    in memory.
    """
    data_queue = Queue(maxsize=queue_size)
    finished = Value('i', 0)

    # Initialize the dump reader
    wikidata = WikidataDumpReader(
        filepath,
        num_processes=num_processes,
        queue_size=queue_size,
        skiplines=skip_lines
    )

    # Define a function to feed items into the queue
    def run_reader():
        wikidata.run(lambda item: save_to_queue(item, data_queue),
                     max_iterations=None, verbose=True)
        with finished.get_lock():
            finished.value = 1

    # Start reader in a separate process
    reader_proc = Process(target=run_reader)
    reader_proc.start()

    # Continuously yield items from the queue to the Dataset generator
    while True:
        # If reader is done AND queue is empty => stop
        if finished.value == 1 and data_queue.empty():
            break
        try:
            item = data_queue.get(timeout=1)
        except:
            continue
        if item:
            yield item

    # Wait for the reader process to exit
    reader_proc.join()

# Now process each chunk file and push to the same Hugging Face repo
HF_REPO_ID = "wikidata"  # Change to your actual repo on Hugging Face

for i in range(112):
    filepath = f"../data/Wikidata/latest-all-chunks/chunk_{i}.json.gz"
    split_name = f"chunk_{i}"

    print(f"Processing {filepath} -> split={split_name}")

    # Create a Dataset from the generator
    ds_chunk = Dataset.from_generator(lambda: chunk_generator(
        filepath,
        num_processes=NUM_PROCESSES,
        queue_size=QUEUE_SIZE,
        skip_lines=SKIPLINES
    ),
    # Optionally specify features= if you know the schema
    # features=Features({...})
    )

    # Push each chunk as a separate "split" under the same dataset repo
    ds_chunk.push_to_hub(HF_REPO_ID, split=split_name)

    print(f"Chunk {i} pushed to {HF_REPO_ID} as {split_name}.")
# Out:
# Processing ../data/Wikidata/latest-all-chunks/chunk_0.json.gz -> split=chunk_0
# Generating train split: 0 examples [00:00, ? examples/s]
# Skipping lines: 0it [00:00, ?it/s]
# Items Processed: 358 | Processing Rate: 119 items/sec
# Items Processed: 1133 | Processing Rate: 189 items/sec
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# File ~/anaconda3/lib/python3.12/site-packages/datasets/builder.py:1624, in GeneratorBasedBuilder._prepare_split_single(self, gen_kwargs, fpath, file_format, max_shard_size, split_info, check_duplicate_keys, job_id)
#    1623 example = self.info.features.encode_example(record) if self.info.features is not None else record
# -> 1624 writer.write(example, key)
#    1625 num_examples_progress_update += 1
#
# File ~/anaconda3/lib/python3.12/site-packages/datasets/arrow_writer.py:495, in ArrowWriter.write(self, example, key, writer_batch_size)
#     493     self.hkey_record = []
# --> 495 self.write_examples_on_file()
#
# File ~/anaconda3/lib/python3.12/site-packages/datasets/arrow_writer.py:453, in ArrowWriter.write_examples_on_file(self)
#     449         batch_examples[col] = [
#     450             row[0][col].to_pylist()[0] if isinstance(row[0][col], (pa.Array, pa.ChunkedArray)) else row[0][col]
#     451             for row in self.current_examples
#     452         ]
# --> 453 self.write_batch(batch_examples=batch_examples)
#     454 self.current_examples = []
#
# File ~/anaconda3/lib/python3.12/site-packages/datasets/arrow_writer.py:563, in ArrowWriter.write_batch(self, batch_examples, writer_batch_size)
#     562 typed_sequence = OptimizedTypedSequence(col_values, type=col_type, try_type=col_try_type, col=col)
# --> 563 arrays.append(pa.array(typed_sequence))
#     564 inferred_features[col] = typed_sequence.get_inferred_type()
#
# File ~/anaconda3/lib/python3.12/site-packages/pyarrow/array.pxi:248, in pyarrow.lib.array()
#
# File ~/anaconda3/lib/python3.12/site-packages/pyarrow/array.pxi:112, in pyarrow.lib._handle_arrow_array_protocol()
#
# File ~/anaconda3/lib/python3.12/site-packages/datasets/arrow_writer.py:188, in TypedSequence.__arrow_array__(self, type)
#     187     trying_cast_to_python_objects = True
# --> 188     out = pa.array(cast_to_python_objects(data, only_1d_for_numpy=True))
#     189 # use smaller integer precisions if possible
#
# File ~/anaconda3/lib/python3.12/site-packages/pyarrow/array.pxi:368, in pyarrow.lib.array()
#
# File ~/anaconda3/lib/python3.12/site-packages/pyarrow/array.pxi:42, in pyarrow.lib._sequence_to_array()
#
# File ~/anaconda3/lib/python3.12/site-packages/pyarrow/error.pxi:155, in pyarrow.lib.pyarrow_internal_check_status()
#
# File ~/anaconda3/lib/python3.12/site-packages/pyarrow/error.pxi:92, in pyarrow.lib.check_status()
#
# ArrowInvalid: cannot mix struct and non-struct, non-null values
#
# During handling of the above exception, another exception occurred:
#
# ArrowInvalid                              Traceback (most recent call last)
# File ~/anaconda3/lib/python3.12/site-packages/datasets/builder.py:1633, in GeneratorBasedBuilder._prepare_split_single(self, gen_kwargs, fpath, file_format, max_shard_size, split_info, check_duplicate_keys, job_id)
#    1632 num_shards = shard_id + 1
# -> 1633 num_examples, num_bytes = writer.finalize()
#    1634 writer.close()
#
# File ~/anaconda3/lib/python3.12/site-packages/datasets/arrow_writer.py:594, in ArrowWriter.finalize(self, close_stream)
#     593     self.hkey_record = []
# --> 594 self.write_examples_on_file()
#     595 # If schema is known, infer features even if no examples were written
#
# File ~/anaconda3/lib/python3.12/site-packages/datasets/arrow_writer.py:453, in ArrowWriter.write_examples_on_file(self)
#     449         batch_examples[col] = [
#     450             row[0][col].to_pylist()[0] if isinstance(row[0][col], (pa.Array, pa.ChunkedArray)) else row[0][col]
#     451             for row in self.current_examples
#     452         ]
# --> 453 self.write_batch(batch_examples=batch_examples)
#     454 self.current_examples = []
#
# File ~/anaconda3/lib/python3.12/site-packages/datasets/arrow_writer.py:563, in ArrowWriter.write_batch(self, batch_examples, writer_batch_size)
#     562 typed_sequence = OptimizedTypedSequence(col_values, type=col_type, try_type=col_try_type, col=col)
# --> 563 arrays.append(pa.array(typed_sequence))
#     564 inferred_features[col] = typed_sequence.get_inferred_type()
#
# File ~/anaconda3/lib/python3.12/site-packages/pyarrow/array.pxi:248, in pyarrow.lib.array()
#
# File ~/anaconda3/lib/python3.12/site-packages/pyarrow/array.pxi:112, in pyarrow.lib._handle_arrow_array_protocol()
#
# File ~/anaconda3/lib/python3.12/site-packages/datasets/arrow_writer.py:188, in TypedSequence.__arrow_array__(self, type)
#     187     trying_cast_to_python_objects = True
# --> 188     out = pa.array(cast_to_python_objects(data, only_1d_for_numpy=True))
#     189 # use smaller integer precisions if possible
#
# File ~/anaconda3/lib/python3.12/site-packages/pyarrow/array.pxi:368, in pyarrow.lib.array()
#
# File ~/anaconda3/lib/python3.12/site-packages/pyarrow/array.pxi:42, in pyarrow.lib._sequence_to_array()
#
# File ~/anaconda3/lib/python3.12/site-packages/pyarrow/error.pxi:155, in pyarrow.lib.pyarrow_internal_check_status()
#
# File ~/anaconda3/lib/python3.12/site-packages/pyarrow/error.pxi:92, in pyarrow.lib.check_status()
#
# ArrowInvalid: cannot mix struct and non-struct, non-null values
#
# The above exception was the direct cause of the following exception:
#
# DatasetGenerationError                    Traceback (most recent call last)
# Cell In[1], line 84
#      81 print(f"Processing {filepath} -> split={split_name}")
#      83 # Create a Dataset from the generator
# ---> 84 ds_chunk = Dataset.from_generator(lambda: chunk_generator(
#      85     filepath,
#      86     num_processes=NUM_PROCESSES,
#      87     queue_size=QUEUE_SIZE,
#      88     skip_lines=SKIPLINES
#      89 ),
#      90 # Optionally specify features= if you know the schema
#      91 # features=Features({...})
#      92 )
#      94 # Push each chunk as a separate "split" under the same dataset repo
#      95 ds_chunk.push_to_hub(HF_REPO_ID, split=split_name)
#
# File ~/anaconda3/lib/python3.12/site-packages/datasets/arrow_dataset.py:1099, in Dataset.from_generator(generator, features, cache_dir, keep_in_memory, gen_kwargs, num_proc, split, **kwargs)
#    1037 """Create a Dataset from a generator.
#    1038
#    1039 Args:
#    (...)
#    1086 ```
#    1087 """
#    1088 from .io.generator import GeneratorDatasetInputStream
#    1090 return GeneratorDatasetInputStream(
#    1091     generator=generator,
#    1092     features=features,
#    1093     cache_dir=cache_dir,
#    1094     keep_in_memory=keep_in_memory,
#    1095     gen_kwargs=gen_kwargs,
#    1096     num_proc=num_proc,
#    1097     split=split,
#    1098     **kwargs,
# -> 1099 ).read()
#
# File ~/anaconda3/lib/python3.12/site-packages/datasets/io/generator.py:49, in GeneratorDatasetInputStream.read(self)
#      46     verification_mode = None
#      47     base_path = None
# ---> 49     self.builder.download_and_prepare(
#      50         download_config=download_config,
#      51         download_mode=download_mode,
#      52         verification_mode=verification_mode,
#      53         base_path=base_path,
#      54         num_proc=self.num_proc,
#      55     )
#      56     dataset = self.builder.as_dataset(
#      57         split=self.builder.config.split, verification_mode=verification_mode, in_memory=self.keep_in_memory
#      58     )
#      59 return dataset
#
# File ~/anaconda3/lib/python3.12/site-packages/datasets/builder.py:924, in DatasetBuilder.download_and_prepare(self, output_dir, download_config, download_mode, verification_mode, dl_manager, base_path, file_format, max_shard_size, num_proc, storage_options, **download_and_prepare_kwargs)
#     922 if num_proc is not None:
#     923     prepare_split_kwargs["num_proc"] = num_proc
# --> 924 self._download_and_prepare(
#     925     dl_manager=dl_manager,
#     926     verification_mode=verification_mode,
#     927     **prepare_split_kwargs,
#     928     **download_and_prepare_kwargs,
#     929 )
#     930 # Sync info
#     931 self.info.dataset_size = sum(split.num_bytes for split in self.info.splits.values())
#
# File ~/anaconda3/lib/python3.12/site-packages/datasets/builder.py:1647, in GeneratorBasedBuilder._download_and_prepare(self, dl_manager, verification_mode, **prepare_splits_kwargs)
#    1646 def _download_and_prepare(self, dl_manager, verification_mode, **prepare_splits_kwargs):
# -> 1647     super()._download_and_prepare(
#    1648         dl_manager,
#    1649         verification_mode,
#    1650         check_duplicate_keys=verification_mode == VerificationMode.BASIC_CHECKS
#    1651         or verification_mode == VerificationMode.ALL_CHECKS,
#    1652         **prepare_splits_kwargs,
#    1653     )
#
# File ~/anaconda3/lib/python3.12/site-packages/datasets/builder.py:999, in DatasetBuilder._download_and_prepare(self, dl_manager, verification_mode, **prepare_split_kwargs)
#     995 split_dict.add(split_generator.split_info)
#     997 try:
#     998     # Prepare split will record examples associated to the split
# --> 999     self._prepare_split(split_generator, **prepare_split_kwargs)
#    1000 except OSError as e:
#    1001     raise OSError(
#    1002         "Cannot find data file. "
#    1003         + (self.manual_download_instructions or "")
#    1004         + "\nOriginal error:\n"
#    1005         + str(e)
#    1006     ) from None
#
# File ~/anaconda3/lib/python3.12/site-packages/datasets/builder.py:1485, in GeneratorBasedBuilder._prepare_split(self, split_generator, check_duplicate_keys, file_format, num_proc, max_shard_size)
#    1483 job_id = 0
#    1484 with pbar:
# -> 1485     for job_id, done, content in self._prepare_split_single(
#    1486         gen_kwargs=gen_kwargs, job_id=job_id, **_prepare_split_args
#    1487     ):
#    1488         if done:
#    1489             result = content
#
# File ~/anaconda3/lib/python3.12/site-packages/datasets/builder.py:1642, in GeneratorBasedBuilder._prepare_split_single(self, gen_kwargs, fpath, file_format, max_shard_size, split_info, check_duplicate_keys, job_id)
#    1640     if isinstance(e, SchemaInferenceError) and e.__context__ is not None:
#    1641         e = e.__context__
# -> 1642     raise DatasetGenerationError("An error occurred while generating the dataset") from e
#    1644 yield job_id, True, (total_num_examples, total_num_bytes, writer._features, num_shards, shard_lengths)
#
# DatasetGenerationError: An error occurred while generating the dataset
# Items Processed: 1963 | Processing Rate: 218 items/sec
# Items Processed: 3087 | Processing Rate: 257 items/sec
# Items Processed: 4382 | Processing Rate: 292 items/sec
# Items Processed: 5284 | Processing Rate: 293 items/sec
