# %% [markdown]
# #### Reading the Wikidata dump ZIP file and saving the IDs of entities and properties to a JSON file (Only the ones connected to the English Wikipedia)

# %%
import sys
sys.path.append('../src')

from wikidata_dumpreader import WikidataDumpReader
from wikidataDB import WikidataID
from multiprocessing import Lock

FILEPATH = '../data/Wikidata/latest-all.json.bz2'
BATCH_SIZE = 1000
NUM_PROCESSES = 4
language = 'en'
sqlitDBlock = Lock()

wikidata = WikidataDumpReader(FILEPATH, num_processes=NUM_PROCESSES, batch_size=BATCH_SIZE, skiplines=0)

def in_en_wiki(item):
    return ('sitelinks' in item) and (f'{language}wiki' in item['sitelinks']) and ((language in item['labels']) or ('mul' in item['labels'])) and ((language in item['descriptions']) or ('mul' in item['descriptions']))

bulk_ids = []
def count_types(item):
    global bulk_ids

    if item is not None:
        if in_en_wiki(item):
            bulk_ids.append({'id': item['id'], 'in_wikipedia': True, 'is_property': False})

            for pid,claim in item.get('claims', {}).items():
                bulk_ids.append({'id': pid, 'in_wikipedia': False, 'is_property': True})

                for c in claim:
                    if ('mainsnak' in c) and ('datavalue' in c['mainsnak']):
                        if (c['mainsnak'].get('datatype', '') == 'wikibase-item'):
                            id = c['mainsnak']['datavalue']['value']['id']
                            bulk_ids.append({'id': id, 'in_wikipedia': False, 'is_property': False})

                        elif (c['mainsnak'].get('datatype', '') == 'wikibase-property'):
                            id = c['mainsnak']['datavalue']['value']['id']
                            bulk_ids.append({'id': id, 'in_wikipedia': False, 'is_property': True})

                        elif (c['mainsnak'].get('datatype', '') == 'quantity') and (c['mainsnak']['datavalue']['value'].get('unit', '1') != '1'):
                            id = c['mainsnak']['datavalue']['value']['unit'].rsplit('/', 1)[1]
                            bulk_ids.append({'id': id, 'in_wikipedia': False, 'is_property': False})

                    if 'qualifiers' in c:
                        for pid, qualifier in c['qualifiers'].items():
                            bulk_ids.append({'id': pid, 'in_wikipedia': False, 'is_property': True})
                            for q in qualifier:
                                if ('datavalue' in q):
                                    if (q['datatype'] == 'wikibase-item'):
                                        id = q['datavalue']['value']['id']
                                        bulk_ids.append({'id': id, 'in_wikipedia': False, 'is_property': False})

                                    elif(q['datatype'] == 'wikibase-property'):
                                        id = q['datavalue']['value']['id']
                                        bulk_ids.append({'id': id, 'in_wikipedia': False, 'is_property': True})

                                    elif (q['datatype'] == 'quantity') and (q['datavalue']['value'].get('unit', '1') != '1'):
                                        id = q['datavalue']['value']['unit'].rsplit('/', 1)[1]
                                        bulk_ids.append({'id': id, 'in_wikipedia': False, 'is_property': False})

            with sqlitDBlock:
                if len(bulk_ids) > BATCH_SIZE:
                    worked = WikidataID.add_bulk_ids(bulk_ids)
                    if worked:
                        bulk_ids = []

async def run_processor():
    await wikidata.run(count_types, max_iterations=None, verbose=True)

await run_processor()

if len(bulk_ids) > 0:
    worked = WikidataID.add_bulk_ids(bulk_ids)
# Out:
# 0it [00:00, ?it/s]
# 999 Lines Processed 	 Line Process Avg: 333 items/sec 	 Memory Usage Avg: 882.04 MB
# 3999 Lines Processed 	 Line Process Avg: 666 items/sec 	 Memory Usage Avg: 1100.55 MB
# 5999 Lines Processed 	 Line Process Avg: 664 items/sec 	 Memory Usage Avg: 1122.13 MB
# 8999 Lines Processed 	 Line Process Avg: 746 items/sec 	 Memory Usage Avg: 1295.25 MB
# 10999 Lines Processed 	 Line Process Avg: 720 items/sec 	 Memory Usage Avg: 1231.59 MB
# 14999 Lines Processed 	 Line Process Avg: 815 items/sec 	 Memory Usage Avg: 1370.82 MB
# 17999 Lines Processed 	 Line Process Avg: 822 items/sec 	 Memory Usage Avg: 1392.98 MB
# 20999 Lines Processed 	 Line Process Avg: 843 items/sec 	 Memory Usage Avg: 1440.78 MB
# 21999 Lines Processed 	 Line Process Avg: 776 items/sec 	 Memory Usage Avg: 1473.58 MB
# 22999 Lines Processed 	 Line Process Avg: 725 items/sec 	 Memory Usage Avg: 1472.30 MB
# 25999 Lines Processed 	 Line Process Avg: 746 items/sec 	 Memory Usage Avg: 1554.64 MB
# 27999 Lines Processed 	 Line Process Avg: 738 items/sec 	 Memory Usage Avg: 1605.77 MB
# 30999 Lines Processed 	 Line Process Avg: 757 items/sec 	 Memory Usage Avg: 1653.77 MB
# 33999 Lines Processed 	 Line Process Avg: 773 items/sec 	 Memory Usage Avg: 1704.51 MB
# 35999 Lines Processed 	 Line Process Avg: 767 items/sec 	 Memory Usage Avg: 1929.69 MB
# 38999 Lines Processed 	 Line Process Avg: 778 items/sec 	 Memory Usage Avg: 2076.79 MB
# 40999 Lines Processed 	 Line Process Avg: 772 items/sec 	 Memory Usage Avg: 2104.40 MB
# 43999 Lines Processed 	 Line Process Avg: 784 items/sec 	 Memory Usage Avg: 2000.27 MB
# 46999 Lines Processed 	 Line Process Avg: 795 items/sec 	 Memory Usage Avg: 1959.47 MB
# 50999 Lines Processed 	 Line Process Avg: 818 items/sec 	 Memory Usage Avg: 2113.64 MB
# 52999 Lines Processed 	 Line Process Avg: 810 items/sec 	 Memory Usage Avg: 2102.63 MB
# 55999 Lines Processed 	 Line Process Avg: 818 items/sec 	 Memory Usage Avg: 2213.48 MB
# 58999 Lines Processed 	 Line Process Avg: 822 items/sec 	 Memory Usage Avg: 2312.05 MB
# 60999 Lines Processed 	 Line Process Avg: 815 items/sec 	 Memory Usage Avg: 2290.12 MB
# 64999 Lines Processed 	 Line Process Avg: 835 items/sec 	 Memory Usage Avg: 2362.95 MB
# 67999 Lines Processed 	 Line Process Avg: 841 items/sec 	 Memory Usage Avg: 2414.71 MB
# 69999 Lines Processed 	 Line Process Avg: 835 items/sec 	 Memory Usage Avg: 2482.05 MB
# 72999 Lines Processed 	 Line Process Avg: 841 items/sec 	 Memory Usage Avg: 2530.34 MB
# 76999 Lines Processed 	 Line Process Avg: 857 items/sec 	 Memory Usage Avg: 2552.70 MB
# 79999 Lines Processed 	 Line Process Avg: 862 items/sec 	 Memory Usage Avg: 2646.64 MB
# 80999 Lines Processed 	 Line Process Avg: 845 items/sec 	 Memory Usage Avg: 2702.32 MB
# 83999 Lines Processed 	 Line Process Avg: 850 items/sec 	 Memory Usage Avg: 2775.47 MB
# 88999 Lines Processed 	 Line Process Avg: 874 items/sec 	 Memory Usage Avg: 2813.84 MB
# 93999 Lines Processed 	 Line Process Avg: 896 items/sec 	 Memory Usage Avg: 2838.80 MB
# 97999 Lines Processed 	 Line Process Avg: 908 items/sec 	 Memory Usage Avg: 2837.46 MB
# 102999 Lines Processed 	 Line Process Avg: 929 items/sec 	 Memory Usage Avg: 2890.49 MB
# 105999 Lines Processed 	 Line Process Avg: 931 items/sec 	 Memory Usage Avg: 2930.77 MB
# 108999 Lines Processed 	 Line Process Avg: 932 items/sec 	 Memory Usage Avg: 3004.97 MB
# 112999 Lines Processed 	 Line Process Avg: 942 items/sec 	 Memory Usage Avg: 3005.20 MB
# 116999 Lines Processed 	 Line Process Avg: 951 items/sec 	 Memory Usage Avg: 2996.57 MB
# 120999 Lines Processed 	 Line Process Avg: 960 items/sec 	 Memory Usage Avg: 3008.97 MB
# 124999 Lines Processed 	 Line Process Avg: 969 items/sec 	 Memory Usage Avg: 3115.47 MB
# 129999 Lines Processed 	 Line Process Avg: 985 items/sec 	 Memory Usage Avg: 3077.18 MB
# 134999 Lines Processed 	 Line Process Avg: 1000 items/sec 	 Memory Usage Avg: 3075.04 MB
# 140999 Lines Processed 	 Line Process Avg: 1022 items/sec 	 Memory Usage Avg: 3058.06 MB
# 147999 Lines Processed 	 Line Process Avg: 1049 items/sec 	 Memory Usage Avg: 3057.21 MB
# 152999 Lines Processed 	 Line Process Avg: 1062 items/sec 	 Memory Usage Avg: 3073.40 MB
# 158999 Lines Processed 	 Line Process Avg: 1081 items/sec 	 Memory Usage Avg: 3073.09 MB
# 163999 Lines Processed 	 Line Process Avg: 1093 items/sec 	 Memory Usage Avg: 3083.77 MB
# 171999 Lines Processed 	 Line Process Avg: 1123 items/sec 	 Memory Usage Avg: 3122.45 MB
# 180999 Lines Processed 	 Line Process Avg: 1159 items/sec 	 Memory Usage Avg: 3121.41 MB
# 187999 Lines Processed 	 Line Process Avg: 1181 items/sec 	 Memory Usage Avg: 3121.31 MB
# 193999 Lines Processed 	 Line Process Avg: 1196 items/sec 	 Memory Usage Avg: 3134.96 MB
# 201999 Lines Processed 	 Line Process Avg: 1223 items/sec 	 Memory Usage Avg: 3172.17 MB
# 206999 Lines Processed 	 Line Process Avg: 1230 items/sec 	 Memory Usage Avg: 3234.68 MB
# 218999 Lines Processed 	 Line Process Avg: 1279 items/sec 	 Memory Usage Avg: 3278.59 MB
# 226999 Lines Processed 	 Line Process Avg: 1303 items/sec 	 Memory Usage Avg: 3295.22 MB
# 232999 Lines Processed 	 Line Process Avg: 1314 items/sec 	 Memory Usage Avg: 3295.09 MB
# 240999 Lines Processed 	 Line Process Avg: 1336 items/sec 	 Memory Usage Avg: 3295.30 MB
# 251999 Lines Processed 	 Line Process Avg: 1374 items/sec 	 Memory Usage Avg: 3293.37 MB
# 261999 Lines Processed 	 Line Process Avg: 1406 items/sec 	 Memory Usage Avg: 3293.36 MB
# 271999 Lines Processed 	 Line Process Avg: 1436 items/sec 	 Memory Usage Avg: 3292.68 MB
# 278999 Lines Processed 	 Line Process Avg: 1450 items/sec 	 Memory Usage Avg: 3292.43 MB
# 285999 Lines Processed 	 Line Process Avg: 1464 items/sec 	 Memory Usage Avg: 3124.23 MB
# 293999 Lines Processed 	 Line Process Avg: 1482 items/sec 	 Memory Usage Avg: 3122.86 MB
# 302999 Lines Processed 	 Line Process Avg: 1504 items/sec 	 Memory Usage Avg: 3122.72 MB
# 308999 Lines Processed 	 Line Process Avg: 1511 items/sec 	 Memory Usage Avg: 3122.72 MB
# 317999 Lines Processed 	 Line Process Avg: 1533 items/sec 	 Memory Usage Avg: 3120.68 MB
# 327999 Lines Processed 	 Line Process Avg: 1558 items/sec 	 Memory Usage Avg: 3115.64 MB
# 337999 Lines Processed 	 Line Process Avg: 1583 items/sec 	 Memory Usage Avg: 3110.65 MB
# 346999 Lines Processed 	 Line Process Avg: 1603 items/sec 	 Memory Usage Avg: 3108.81 MB
# 354999 Lines Processed 	 Line Process Avg: 1616 items/sec 	 Memory Usage Avg: 3106.89 MB
# 362999 Lines Processed 	 Line Process Avg: 1630 items/sec 	 Memory Usage Avg: 3106.91 MB
# 370999 Lines Processed 	 Line Process Avg: 1644 items/sec 	 Memory Usage Avg: 3099.25 MB
# 377999 Lines Processed 	 Line Process Avg: 1653 items/sec 	 Memory Usage Avg: 3099.02 MB
# 385999 Lines Processed 	 Line Process Avg: 1666 items/sec 	 Memory Usage Avg: 3099.00 MB
# 394999 Lines Processed 	 Line Process Avg: 1683 items/sec 	 Memory Usage Avg: 3088.85 MB
# 402999 Lines Processed 	 Line Process Avg: 1695 items/sec 	 Memory Usage Avg: 3161.92 MB
# 412999 Lines Processed 	 Line Process Avg: 1715 items/sec 	 Memory Usage Avg: 3251.75 MB
# 423999 Lines Processed 	 Line Process Avg: 1739 items/sec 	 Memory Usage Avg: 3265.95 MB
# 432999 Lines Processed 	 Line Process Avg: 1755 items/sec 	 Memory Usage Avg: 3263.19 MB
# 446999 Lines Processed 	 Line Process Avg: 1790 items/sec 	 Memory Usage Avg: 3254.42 MB
# 458999 Lines Processed 	 Line Process Avg: 1816 items/sec 	 Memory Usage Avg: 3248.42 MB
# 474999 Lines Processed 	 Line Process Avg: 1857 items/sec 	 Memory Usage Avg: 3248.38 MB
# 487999 Lines Processed 	 Line Process Avg: 1885 items/sec 	 Memory Usage Avg: 3247.41 MB
# 502999 Lines Processed 	 Line Process Avg: 1921 items/sec 	 Memory Usage Avg: 3167.22 MB
# 514999 Lines Processed 	 Line Process Avg: 1944 items/sec 	 Memory Usage Avg: 3142.32 MB
# 526999 Lines Processed 	 Line Process Avg: 1968 items/sec 	 Memory Usage Avg: 3128.13 MB
# 533999 Lines Processed 	 Line Process Avg: 1971 items/sec 	 Memory Usage Avg: 3125.99 MB
# 538999 Lines Processed 	 Line Process Avg: 1968 items/sec 	 Memory Usage Avg: 3126.06 MB
# 547999 Lines Processed 	 Line Process Avg: 1979 items/sec 	 Memory Usage Avg: 3121.89 MB
# 556999 Lines Processed 	 Line Process Avg: 1990 items/sec 	 Memory Usage Avg: 3121.87 MB
# 565999 Lines Processed 	 Line Process Avg: 2001 items/sec 	 Memory Usage Avg: 3120.01 MB
# 572999 Lines Processed 	 Line Process Avg: 2004 items/sec 	 Memory Usage Avg: 3142.90 MB
# 581999 Lines Processed 	 Line Process Avg: 2014 items/sec 	 Memory Usage Avg: 3165.19 MB
# 588999 Lines Processed 	 Line Process Avg: 2018 items/sec 	 Memory Usage Avg: 3194.68 MB
# 597999 Lines Processed 	 Line Process Avg: 2028 items/sec 	 Memory Usage Avg: 3239.39 MB
# 603999 Lines Processed 	 Line Process Avg: 2027 items/sec 	 Memory Usage Avg: 3299.26 MB
# 612999 Lines Processed 	 Line Process Avg: 2037 items/sec 	 Memory Usage Avg: 3314.59 MB
# 618999 Lines Processed 	 Line Process Avg: 2037 items/sec 	 Memory Usage Avg: 3358.14 MB
# 628999 Lines Processed 	 Line Process Avg: 2049 items/sec 	 Memory Usage Avg: 3395.42 MB
# 640999 Lines Processed 	 Line Process Avg: 2068 items/sec 	 Memory Usage Avg: 3388.41 MB
# 658999 Lines Processed 	 Line Process Avg: 2106 items/sec 	 Memory Usage Avg: 3407.39 MB
# 673999 Lines Processed 	 Line Process Avg: 2133 items/sec 	 Memory Usage Avg: 3427.71 MB
# 683999 Lines Processed 	 Line Process Avg: 2144 items/sec 	 Memory Usage Avg: 3453.54 MB
# 693999 Lines Processed 	 Line Process Avg: 2155 items/sec 	 Memory Usage Avg: 3478.78 MB
# 702999 Lines Processed 	 Line Process Avg: 2162 items/sec 	 Memory Usage Avg: 3558.40 MB
# 715999 Lines Processed 	 Line Process Avg: 2182 items/sec 	 Memory Usage Avg: 3554.50 MB
# 728999 Lines Processed 	 Line Process Avg: 2201 items/sec 	 Memory Usage Avg: 3552.54 MB
# 745999 Lines Processed 	 Line Process Avg: 2233 items/sec 	 Memory Usage Avg: 3542.52 MB
# 755999 Lines Processed 	 Line Process Avg: 2242 items/sec 	 Memory Usage Avg: 3542.52 MB
# 768999 Lines Processed 	 Line Process Avg: 2260 items/sec 	 Memory Usage Avg: 3537.77 MB
# 781999 Lines Processed 	 Line Process Avg: 2277 items/sec 	 Memory Usage Avg: 3534.80 MB
# 792999 Lines Processed 	 Line Process Avg: 2288 items/sec 	 Memory Usage Avg: 3534.65 MB
# 802999 Lines Processed 	 Line Process Avg: 2297 items/sec 	 Memory Usage Avg: 3530.71 MB
# 810999 Lines Processed 	 Line Process Avg: 2300 items/sec 	 Memory Usage Avg: 3526.71 MB
# 819999 Lines Processed 	 Line Process Avg: 2306 items/sec 	 Memory Usage Avg: 3523.74 MB
# 830999 Lines Processed 	 Line Process Avg: 2318 items/sec 	 Memory Usage Avg: 3520.62 MB
# 842999 Lines Processed 	 Line Process Avg: 2330 items/sec 	 Memory Usage Avg: 3516.54 MB
# 854999 Lines Processed 	 Line Process Avg: 2344 items/sec 	 Memory Usage Avg: 3514.54 MB
# 864999 Lines Processed 	 Line Process Avg: 2352 items/sec 	 Memory Usage Avg: 3511.49 MB
# 876999 Lines Processed 	 Line Process Avg: 2365 items/sec 	 Memory Usage Avg: 3508.56 MB
# 884999 Lines Processed 	 Line Process Avg: 2367 items/sec 	 Memory Usage Avg: 3506.71 MB
# 900999 Lines Processed 	 Line Process Avg: 2391 items/sec 	 Memory Usage Avg: 3506.65 MB
# 921999 Lines Processed 	 Line Process Avg: 2427 items/sec 	 Memory Usage Avg: 3501.61 MB
# 947999 Lines Processed 	 Line Process Avg: 2476 items/sec 	 Memory Usage Avg: 3500.62 MB
# 973999 Lines Processed 	 Line Process Avg: 2524 items/sec 	 Memory Usage Avg: 3443.94 MB
# 993999 Lines Processed 	 Line Process Avg: 2556 items/sec 	 Memory Usage Avg: 3444.07 MB
# 1006999 Lines Processed 	 Line Process Avg: 2569 items/sec 	 Memory Usage Avg: 3441.31 MB
# 1021999 Lines Processed 	 Line Process Avg: 2588 items/sec 	 Memory Usage Avg: 3430.27 MB
# 1037999 Lines Processed 	 Line Process Avg: 2608 items/sec 	 Memory Usage Avg: 3426.20 MB
# 1050999 Lines Processed 	 Line Process Avg: 2621 items/sec 	 Memory Usage Avg: 3426.19 MB
# 1065999 Lines Processed 	 Line Process Avg: 2639 items/sec 	 Memory Usage Avg: 3425.23 MB
# 1079999 Lines Processed 	 Line Process Avg: 2654 items/sec 	 Memory Usage Avg: 3424.19 MB
# 1094999 Lines Processed 	 Line Process Avg: 2670 items/sec 	 Memory Usage Avg: 3419.31 MB
# 1110999 Lines Processed 	 Line Process Avg: 2689 items/sec 	 Memory Usage Avg: 3416.43 MB
# 1125999 Lines Processed 	 Line Process Avg: 2706 items/sec 	 Memory Usage Avg: 3414.28 MB
# 1140999 Lines Processed 	 Line Process Avg: 2722 items/sec 	 Memory Usage Avg: 3411.44 MB
# 1154999 Lines Processed 	 Line Process Avg: 2736 items/sec 	 Memory Usage Avg: 3409.45 MB
# 1168999 Lines Processed 	 Line Process Avg: 2749 items/sec 	 Memory Usage Avg: 3408.34 MB
# 1189999 Lines Processed 	 Line Process Avg: 2779 items/sec 	 Memory Usage Avg: 3392.44 MB
# 1209999 Lines Processed 	 Line Process Avg: 2806 items/sec 	 Memory Usage Avg: 3390.44 MB
# 1229999 Lines Processed 	 Line Process Avg: 2833 items/sec 	 Memory Usage Avg: 3389.44 MB
# 1245999 Lines Processed 	 Line Process Avg: 2850 items/sec 	 Memory Usage Avg: 3386.45 MB
# 1262999 Lines Processed 	 Line Process Avg: 2869 items/sec 	 Memory Usage Avg: 3382.30 MB
# 1275999 Lines Processed 	 Line Process Avg: 2879 items/sec 	 Memory Usage Avg: 3380.18 MB
# 1296999 Lines Processed 	 Line Process Avg: 2907 items/sec 	 Memory Usage Avg: 3376.20 MB
# 1324999 Lines Processed 	 Line Process Avg: 2950 items/sec 	 Memory Usage Avg: 3355.09 MB
# 1352999 Lines Processed 	 Line Process Avg: 2992 items/sec 	 Memory Usage Avg: 3344.45 MB
# 1374999 Lines Processed 	 Line Process Avg: 3021 items/sec 	 Memory Usage Avg: 3337.46 MB
# 1387999 Lines Processed 	 Line Process Avg: 3029 items/sec 	 Memory Usage Avg: 3336.37 MB
# 1400999 Lines Processed 	 Line Process Avg: 3038 items/sec 	 Memory Usage Avg: 3335.46 MB
# 1419999 Lines Processed 	 Line Process Avg: 3059 items/sec 	 Memory Usage Avg: 3332.55 MB
# 1439999 Lines Processed 	 Line Process Avg: 3082 items/sec 	 Memory Usage Avg: 3332.56 MB
# 1464999 Lines Processed 	 Line Process Avg: 3115 items/sec 	 Memory Usage Avg: 3330.67 MB
# 1489999 Lines Processed 	 Line Process Avg: 3148 items/sec 	 Memory Usage Avg: 3328.67 MB
# 1502999 Lines Processed 	 Line Process Avg: 3155 items/sec 	 Memory Usage Avg: 3328.24 MB
# 1519999 Lines Processed 	 Line Process Avg: 3171 items/sec 	 Memory Usage Avg: 3325.37 MB
# 1535999 Lines Processed 	 Line Process Avg: 3184 items/sec 	 Memory Usage Avg: 3323.48 MB
# 1554999 Lines Processed 	 Line Process Avg: 3203 items/sec 	 Memory Usage Avg: 3319.23 MB
# 1567999 Lines Processed 	 Line Process Avg: 3208 items/sec 	 Memory Usage Avg: 3319.18 MB
# 1577999 Lines Processed 	 Line Process Avg: 3211 items/sec 	 Memory Usage Avg: 3317.47 MB
# 1585999 Lines Processed 	 Line Process Avg: 3205 items/sec 	 Memory Usage Avg: 3421.86 MB
# 1595999 Lines Processed 	 Line Process Avg: 3208 items/sec 	 Memory Usage Avg: 3353.65 MB
# 1605999 Lines Processed 	 Line Process Avg: 3208 items/sec 	 Memory Usage Avg: 3351.61 MB
# 1613999 Lines Processed 	 Line Process Avg: 3205 items/sec 	 Memory Usage Avg: 3348.42 MB
# 1621999 Lines Processed 	 Line Process Avg: 3202 items/sec 	 Memory Usage Avg: 3344.75 MB
# 1630999 Lines Processed 	 Line Process Avg: 3201 items/sec 	 Memory Usage Avg: 3343.62 MB
# 1644999 Lines Processed 	 Line Process Avg: 3209 items/sec 	 Memory Usage Avg: 3335.70 MB
# 1662999 Lines Processed 	 Line Process Avg: 3225 items/sec 	 Memory Usage Avg: 3329.78 MB
# 1674999 Lines Processed 	 Line Process Avg: 3230 items/sec 	 Memory Usage Avg: 3327.78 MB
# 1687999 Lines Processed 	 Line Process Avg: 3236 items/sec 	 Memory Usage Avg: 3325.78 MB
# 1709999 Lines Processed 	 Line Process Avg: 3259 items/sec 	 Memory Usage Avg: 3319.84 MB
# 1729999 Lines Processed 	 Line Process Avg: 3279 items/sec 	 Memory Usage Avg: 3318.84 MB
# 1743999 Lines Processed 	 Line Process Avg: 3287 items/sec 	 Memory Usage Avg: 3313.80 MB
# 1759999 Lines Processed 	 Line Process Avg: 3298 items/sec 	 Memory Usage Avg: 3310.74 MB
# 1777999 Lines Processed 	 Line Process Avg: 3313 items/sec 	 Memory Usage Avg: 3306.87 MB
# 1792999 Lines Processed 	 Line Process Avg: 3323 items/sec 	 Memory Usage Avg: 3305.81 MB
# 1808999 Lines Processed 	 Line Process Avg: 3334 items/sec 	 Memory Usage Avg: 3303.80 MB
# 1827999 Lines Processed 	 Line Process Avg: 3348 items/sec 	 Memory Usage Avg: 3301.87 MB
# 1846999 Lines Processed 	 Line Process Avg: 3366 items/sec 	 Memory Usage Avg: 3301.86 MB
# 1858999 Lines Processed 	 Line Process Avg: 3370 items/sec 	 Memory Usage Avg: 3336.04 MB
# 1866999 Lines Processed 	 Line Process Avg: 3366 items/sec 	 Memory Usage Avg: 3335.81 MB
# 1881999 Lines Processed 	 Line Process Avg: 3375 items/sec 	 Memory Usage Avg: 3327.70 MB
# 1891999 Lines Processed 	 Line Process Avg: 3375 items/sec 	 Memory Usage Avg: 3327.68 MB
# 1910999 Lines Processed 	 Line Process Avg: 3390 items/sec 	 Memory Usage Avg: 3327.69 MB
# 1925999 Lines Processed 	 Line Process Avg: 3399 items/sec 	 Memory Usage Avg: 3325.62 MB
# 1943999 Lines Processed 	 Line Process Avg: 3412 items/sec 	 Memory Usage Avg: 3307.62 MB
# 1977999 Lines Processed 	 Line Process Avg: 3454 items/sec 	 Memory Usage Avg: 3298.79 MB
# 2009999 Lines Processed 	 Line Process Avg: 3491 items/sec 	 Memory Usage Avg: 3291.90 MB
# 2035999 Lines Processed 	 Line Process Avg: 3518 items/sec 	 Memory Usage Avg: 3288.95 MB
# 2052999 Lines Processed 	 Line Process Avg: 3529 items/sec 	 Memory Usage Avg: 3284.93 MB
# 2070999 Lines Processed 	 Line Process Avg: 3542 items/sec 	 Memory Usage Avg: 3285.04 MB
# 2087999 Lines Processed 	 Line Process Avg: 3551 items/sec 	 Memory Usage Avg: 3282.78 MB
# 2112999 Lines Processed 	 Line Process Avg: 3575 items/sec 	 Memory Usage Avg: 3279.97 MB
# 2136999 Lines Processed 	 Line Process Avg: 3597 items/sec 	 Memory Usage Avg: 3272.87 MB
# 2150999 Lines Processed 	 Line Process Avg: 3604 items/sec 	 Memory Usage Avg: 3268.77 MB
# 2165999 Lines Processed 	 Line Process Avg: 3611 items/sec 	 Memory Usage Avg: 3267.87 MB
# 2175999 Lines Processed 	 Line Process Avg: 3610 items/sec 	 Memory Usage Avg: 3396.43 MB
# 2180999 Lines Processed 	 Line Process Avg: 3600 items/sec 	 Memory Usage Avg: 3555.11 MB
# 2191999 Lines Processed 	 Line Process Avg: 3600 items/sec 	 Memory Usage Avg: 3387.81 MB
# 2209999 Lines Processed 	 Line Process Avg: 3612 items/sec 	 Memory Usage Avg: 3340.11 MB
# 2219999 Lines Processed 	 Line Process Avg: 3610 items/sec 	 Memory Usage Avg: 3335.00 MB
# 2233999 Lines Processed 	 Line Process Avg: 3615 items/sec 	 Memory Usage Avg: 3324.82 MB
# 2255999 Lines Processed 	 Line Process Avg: 3633 items/sec 	 Memory Usage Avg: 3315.82 MB
# 2270999 Lines Processed 	 Line Process Avg: 3640 items/sec 	 Memory Usage Avg: 3419.31 MB
# 2283999 Lines Processed 	 Line Process Avg: 3643 items/sec 	 Memory Usage Avg: 3349.04 MB
# 2299999 Lines Processed 	 Line Process Avg: 3651 items/sec 	 Memory Usage Avg: 3334.17 MB
# 2315999 Lines Processed 	 Line Process Avg: 3659 items/sec 	 Memory Usage Avg: 3329.84 MB
# 2348999 Lines Processed 	 Line Process Avg: 3692 items/sec 	 Memory Usage Avg: 3323.11 MB
# 2369999 Lines Processed 	 Line Process Avg: 3709 items/sec 	 Memory Usage Avg: 3320.03 MB
# 2386999 Lines Processed 	 Line Process Avg: 3718 items/sec 	 Memory Usage Avg: 3318.10 MB
# 2401999 Lines Processed 	 Line Process Avg: 3724 items/sec 	 Memory Usage Avg: 3318.17 MB
# 2416999 Lines Processed 	 Line Process Avg: 3730 items/sec 	 Memory Usage Avg: 3317.02 MB
# 2431999 Lines Processed 	 Line Process Avg: 3736 items/sec 	 Memory Usage Avg: 3316.97 MB
# 2441999 Lines Processed 	 Line Process Avg: 3732 items/sec 	 Memory Usage Avg: 3316.77 MB
# 2450999 Lines Processed 	 Line Process Avg: 3730 items/sec 	 Memory Usage Avg: 3316.76 MB
# 2460999 Lines Processed 	 Line Process Avg: 3728 items/sec 	 Memory Usage Avg: 3316.96 MB
# 2485999 Lines Processed 	 Line Process Avg: 3749 items/sec 	 Memory Usage Avg: 3307.96 MB
# 2497999 Lines Processed 	 Line Process Avg: 3750 items/sec 	 Memory Usage Avg: 3308.00 MB
# 2511999 Lines Processed 	 Line Process Avg: 3754 items/sec 	 Memory Usage Avg: 3307.95 MB
# 2519999 Lines Processed 	 Line Process Avg: 3749 items/sec 	 Memory Usage Avg: 3361.96 MB
# 2526999 Lines Processed 	 Line Process Avg: 3743 items/sec 	 Memory Usage Avg: 3356.19 MB
# 2530999 Lines Processed 	 Line Process Avg: 3732 items/sec 	 Memory Usage Avg: 3604.90 MB
# 2541999 Lines Processed 	 Line Process Avg: 3732 items/sec 	 Memory Usage Avg: 3396.00 MB
# 2557999 Lines Processed 	 Line Process Avg: 3737 items/sec 	 Memory Usage Avg: 3376.09 MB
# 2566999 Lines Processed 	 Line Process Avg: 3733 items/sec 	 Memory Usage Avg: 3375.26 MB
# 2570999 Lines Processed 	 Line Process Avg: 3723 items/sec 	 Memory Usage Avg: 3515.66 MB
# 2581999 Lines Processed 	 Line Process Avg: 3723 items/sec 	 Memory Usage Avg: 3408.40 MB
# 2591999 Lines Processed 	 Line Process Avg: 3721 items/sec 	 Memory Usage Avg: 3397.11 MB
# 2610999 Lines Processed 	 Line Process Avg: 3732 items/sec 	 Memory Usage Avg: 3387.94 MB
# 2625999 Lines Processed 	 Line Process Avg: 3738 items/sec 	 Memory Usage Avg: 3387.05 MB
# 2642999 Lines Processed 	 Line Process Avg: 3746 items/sec 	 Memory Usage Avg: 3386.25 MB
# 2680999 Lines Processed 	 Line Process Avg: 3783 items/sec 	 Memory Usage Avg: 3325.37 MB
# 2701999 Lines Processed 	 Line Process Avg: 3797 items/sec 	 Memory Usage Avg: 3324.23 MB
# 2724999 Lines Processed 	 Line Process Avg: 3813 items/sec 	 Memory Usage Avg: 3322.12 MB
# 2740999 Lines Processed 	 Line Process Avg: 3820 items/sec 	 Memory Usage Avg: 3320.21 MB
# 2760999 Lines Processed 	 Line Process Avg: 3831 items/sec 	 Memory Usage Avg: 3318.90 MB
# 2784999 Lines Processed 	 Line Process Avg: 3849 items/sec 	 Memory Usage Avg: 3318.90 MB
# 2788999 Lines Processed 	 Line Process Avg: 3838 items/sec 	 Memory Usage Avg: 3521.12 MB
# 2790999 Lines Processed 	 Line Process Avg: 3825 items/sec 	 Memory Usage Avg: 3879.20 MB
# 2795999 Lines Processed 	 Line Process Avg: 3815 items/sec 	 Memory Usage Avg: 3846.83 MB
# 2806999 Lines Processed 	 Line Process Avg: 3814 items/sec 	 Memory Usage Avg: 3470.34 MB
# 2812999 Lines Processed 	 Line Process Avg: 3807 items/sec 	 Memory Usage Avg: 3588.47 MB
# 2818999 Lines Processed 	 Line Process Avg: 3800 items/sec 	 Memory Usage Avg: 3514.16 MB
# 2825999 Lines Processed 	 Line Process Avg: 3794 items/sec 	 Memory Usage Avg: 3512.34 MB
# 2833999 Lines Processed 	 Line Process Avg: 3789 items/sec 	 Memory Usage Avg: 3512.54 MB
# 2839999 Lines Processed 	 Line Process Avg: 3780 items/sec 	 Memory Usage Avg: 3651.20 MB
# 2846999 Lines Processed 	 Line Process Avg: 3776 items/sec 	 Memory Usage Avg: 3538.24 MB
# 2852999 Lines Processed 	 Line Process Avg: 3767 items/sec 	 Memory Usage Avg: 3821.69 MB
# 2859999 Lines Processed 	 Line Process Avg: 3762 items/sec 	 Memory Usage Avg: 3565.57 MB
# 2865999 Lines Processed 	 Line Process Avg: 3755 items/sec 	 Memory Usage Avg: 3561.34 MB
# 2870999 Lines Processed 	 Line Process Avg: 3747 items/sec 	 Memory Usage Avg: 3597.96 MB
# 2880999 Lines Processed 	 Line Process Avg: 3745 items/sec 	 Memory Usage Avg: 3558.28 MB
# 2896999 Lines Processed 	 Line Process Avg: 3751 items/sec 	 Memory Usage Avg: 3527.30 MB
# 2905999 Lines Processed 	 Line Process Avg: 3748 items/sec 	 Memory Usage Avg: 3525.17 MB
# 2912999 Lines Processed 	 Line Process Avg: 3742 items/sec 	 Memory Usage Avg: 3650.63 MB
# 2917999 Lines Processed 	 Line Process Avg: 3734 items/sec 	 Memory Usage Avg: 3829.85 MB
# 2926999 Lines Processed 	 Line Process Avg: 3731 items/sec 	 Memory Usage Avg: 3578.34 MB
# 2932999 Lines Processed 	 Line Process Avg: 3724 items/sec 	 Memory Usage Avg: 3576.37 MB
# 2939999 Lines Processed 	 Line Process Avg: 3719 items/sec 	 Memory Usage Avg: 3576.42 MB
# 2946999 Lines Processed 	 Line Process Avg: 3714 items/sec 	 Memory Usage Avg: 3611.96 MB
# 2954999 Lines Processed 	 Line Process Avg: 3710 items/sec 	 Memory Usage Avg: 3551.67 MB
# 2959999 Lines Processed 	 Line Process Avg: 3702 items/sec 	 Memory Usage Avg: 3567.59 MB
# 2963999 Lines Processed 	 Line Process Avg: 3693 items/sec 	 Memory Usage Avg: 3636.21 MB
# 2967999 Lines Processed 	 Line Process Avg: 3685 items/sec 	 Memory Usage Avg: 3753.64 MB
# 2970999 Lines Processed 	 Line Process Avg: 3675 items/sec 	 Memory Usage Avg: 3872.04 MB
# 2979999 Lines Processed 	 Line Process Avg: 3672 items/sec 	 Memory Usage Avg: 3656.49 MB
# 2986999 Lines Processed 	 Line Process Avg: 3667 items/sec 	 Memory Usage Avg: 3649.29 MB
# 2999999 Lines Processed 	 Line Process Avg: 3670 items/sec 	 Memory Usage Avg: 3602.31 MB
# 3013999 Lines Processed 	 Line Process Avg: 3673 items/sec 	 Memory Usage Avg: 3595.23 MB
# 3037999 Lines Processed 	 Line Process Avg: 3689 items/sec 	 Memory Usage Avg: 3563.42 MB
# 3058999 Lines Processed 	 Line Process Avg: 3701 items/sec 	 Memory Usage Avg: 3557.43 MB
# 3072999 Lines Processed 	 Line Process Avg: 3704 items/sec 	 Memory Usage Avg: 3552.40 MB
# 3084999 Lines Processed 	 Line Process Avg: 3705 items/sec 	 Memory Usage Avg: 3539.38 MB
# 3096999 Lines Processed 	 Line Process Avg: 3705 items/sec 	 Memory Usage Avg: 3539.45 MB
# 3104999 Lines Processed 	 Line Process Avg: 3702 items/sec 	 Memory Usage Avg: 3539.35 MB
# 3121999 Lines Processed 	 Line Process Avg: 3709 items/sec 	 Memory Usage Avg: 3537.36 MB
# 3133999 Lines Processed 	 Line Process Avg: 3710 items/sec 	 Memory Usage Avg: 3529.44 MB
# 3148999 Lines Processed 	 Line Process Avg: 3715 items/sec 	 Memory Usage Avg: 3513.43 MB
# 3156999 Lines Processed 	 Line Process Avg: 3711 items/sec 	 Memory Usage Avg: 3512.44 MB
# 3162999 Lines Processed 	 Line Process Avg: 3704 items/sec 	 Memory Usage Avg: 3744.22 MB
# 3166999 Lines Processed 	 Line Process Avg: 3696 items/sec 	 Memory Usage Avg: 3813.93 MB
# 3169999 Lines Processed 	 Line Process Avg: 3685 items/sec 	 Memory Usage Avg: 4070.70 MB
# 3173999 Lines Processed 	 Line Process Avg: 3677 items/sec 	 Memory Usage Avg: 3917.17 MB
# 3176999 Lines Processed 	 Line Process Avg: 3668 items/sec 	 Memory Usage Avg: 3957.15 MB
# 3178999 Lines Processed 	 Line Process Avg: 3657 items/sec 	 Memory Usage Avg: 4030.91 MB
# 3186999 Lines Processed 	 Line Process Avg: 3654 items/sec 	 Memory Usage Avg: 3705.22 MB
# 3193999 Lines Processed 	 Line Process Avg: 3649 items/sec 	 Memory Usage Avg: 3688.38 MB
# 3200999 Lines Processed 	 Line Process Avg: 3645 items/sec 	 Memory Usage Avg: 3684.35 MB
# 3209999 Lines Processed 	 Line Process Avg: 3643 items/sec 	 Memory Usage Avg: 3682.45 MB
# 3216999 Lines Processed 	 Line Process Avg: 3638 items/sec 	 Memory Usage Avg: 3715.46 MB
# 3222999 Lines Processed 	 Line Process Avg: 3633 items/sec 	 Memory Usage Avg: 3682.12 MB
# 3232999 Lines Processed 	 Line Process Avg: 3632 items/sec 	 Memory Usage Avg: 3706.89 MB
# 3239999 Lines Processed 	 Line Process Avg: 3627 items/sec 	 Memory Usage Avg: 3679.45 MB
# 3248999 Lines Processed 	 Line Process Avg: 3623 items/sec 	 Memory Usage Avg: 3679.50 MB
# 3258999 Lines Processed 	 Line Process Avg: 3623 items/sec 	 Memory Usage Avg: 3616.43 MB
# 3295999 Lines Processed 	 Line Process Avg: 3652 items/sec 	 Memory Usage Avg: 3552.53 MB
# 3321999 Lines Processed 	 Line Process Avg: 3669 items/sec 	 Memory Usage Avg: 3548.54 MB
# 3334999 Lines Processed 	 Line Process Avg: 3670 items/sec 	 Memory Usage Avg: 3546.33 MB
# 3350999 Lines Processed 	 Line Process Avg: 3675 items/sec 	 Memory Usage Avg: 3545.21 MB
# 3365999 Lines Processed 	 Line Process Avg: 3681 items/sec 	 Memory Usage Avg: 3539.29 MB
# 3380999 Lines Processed 	 Line Process Avg: 3685 items/sec 	 Memory Usage Avg: 3538.41 MB
# 3396999 Lines Processed 	 Line Process Avg: 3689 items/sec 	 Memory Usage Avg: 3538.57 MB
# 3412999 Lines Processed 	 Line Process Avg: 3695 items/sec 	 Memory Usage Avg: 3538.46 MB
# 3426999 Lines Processed 	 Line Process Avg: 3698 items/sec 	 Memory Usage Avg: 3538.34 MB
# 3435999 Lines Processed 	 Line Process Avg: 3696 items/sec 	 Memory Usage Avg: 3538.22 MB
# 3442999 Lines Processed 	 Line Process Avg: 3690 items/sec 	 Memory Usage Avg: 3538.01 MB
# 3448999 Lines Processed 	 Line Process Avg: 3686 items/sec 	 Memory Usage Avg: 3538.29 MB
# 3453999 Lines Processed 	 Line Process Avg: 3679 items/sec 	 Memory Usage Avg: 3570.53 MB
# 3458999 Lines Processed 	 Line Process Avg: 3673 items/sec 	 Memory Usage Avg: 3584.46 MB
# 3464999 Lines Processed 	 Line Process Avg: 3667 items/sec 	 Memory Usage Avg: 3574.18 MB
# 3470999 Lines Processed 	 Line Process Avg: 3662 items/sec 	 Memory Usage Avg: 3571.33 MB
# 3475999 Lines Processed 	 Line Process Avg: 3655 items/sec 	 Memory Usage Avg: 3598.79 MB
# 3480999 Lines Processed 	 Line Process Avg: 3648 items/sec 	 Memory Usage Avg: 3747.81 MB
# 3483999 Lines Processed 	 Line Process Avg: 3640 items/sec 	 Memory Usage Avg: 3907.80 MB
# 3487999 Lines Processed 	 Line Process Avg: 3631 items/sec 	 Memory Usage Avg: 3908.71 MB
# 3491999 Lines Processed 	 Line Process Avg: 3624 items/sec 	 Memory Usage Avg: 3845.14 MB
# 3494999 Lines Processed 	 Line Process Avg: 3616 items/sec 	 Memory Usage Avg: 3842.37 MB
# 3497999 Lines Processed 	 Line Process Avg: 3608 items/sec 	 Memory Usage Avg: 3952.73 MB
# 3500999 Lines Processed 	 Line Process Avg: 3600 items/sec 	 Memory Usage Avg: 3949.71 MB
# 3504999 Lines Processed 	 Line Process Avg: 3592 items/sec 	 Memory Usage Avg: 3954.27 MB
# 3507999 Lines Processed 	 Line Process Avg: 3585 items/sec 	 Memory Usage Avg: 3990.19 MB
# 3510999 Lines Processed 	 Line Process Avg: 3577 items/sec 	 Memory Usage Avg: 4028.14 MB
# 3513999 Lines Processed 	 Line Process Avg: 3569 items/sec 	 Memory Usage Avg: 4037.00 MB
# 3516999 Lines Processed 	 Line Process Avg: 3562 items/sec 	 Memory Usage Avg: 4020.07 MB
# 3519999 Lines Processed 	 Line Process Avg: 3554 items/sec 	 Memory Usage Avg: 4003.04 MB
# 3522999 Lines Processed 	 Line Process Avg: 3546 items/sec 	 Memory Usage Avg: 4007.47 MB
# 3526999 Lines Processed 	 Line Process Avg: 3538 items/sec 	 Memory Usage Avg: 4026.26 MB
# 3530999 Lines Processed 	 Line Process Avg: 3531 items/sec 	 Memory Usage Avg: 3945.55 MB
# 3533999 Lines Processed 	 Line Process Avg: 3524 items/sec 	 Memory Usage Avg: 3945.38 MB
# 3536999 Lines Processed 	 Line Process Avg: 3517 items/sec 	 Memory Usage Avg: 3965.54 MB
# 3540999 Lines Processed 	 Line Process Avg: 3510 items/sec 	 Memory Usage Avg: 3997.84 MB
# 3543999 Lines Processed 	 Line Process Avg: 3502 items/sec 	 Memory Usage Avg: 3998.00 MB
# 3547999 Lines Processed 	 Line Process Avg: 3496 items/sec 	 Memory Usage Avg: 3996.63 MB
# 3551999 Lines Processed 	 Line Process Avg: 3488 items/sec 	 Memory Usage Avg: 3992.65 MB
# 3554999 Lines Processed 	 Line Process Avg: 3482 items/sec 	 Memory Usage Avg: 3963.62 MB
# 3558999 Lines Processed 	 Line Process Avg: 3475 items/sec 	 Memory Usage Avg: 3953.91 MB
# 3562999 Lines Processed 	 Line Process Avg: 3469 items/sec 	 Memory Usage Avg: 3958.39 MB
# 3565999 Lines Processed 	 Line Process Avg: 3462 items/sec 	 Memory Usage Avg: 4001.42 MB
# 3570999 Lines Processed 	 Line Process Avg: 3455 items/sec 	 Memory Usage Avg: 3958.40 MB
# 3574999 Lines Processed 	 Line Process Avg: 3448 items/sec 	 Memory Usage Avg: 3960.57 MB
# 3577999 Lines Processed 	 Line Process Avg: 3442 items/sec 	 Memory Usage Avg: 3958.97 MB
# 3581999 Lines Processed 	 Line Process Avg: 3436 items/sec 	 Memory Usage Avg: 3959.69 MB
# 3584999 Lines Processed 	 Line Process Avg: 3428 items/sec 	 Memory Usage Avg: 4047.79 MB
# 3588999 Lines Processed 	 Line Process Avg: 3422 items/sec 	 Memory Usage Avg: 3963.29 MB
# 3592999 Lines Processed 	 Line Process Avg: 3415 items/sec 	 Memory Usage Avg: 3960.41 MB
# 3595999 Lines Processed 	 Line Process Avg: 3409 items/sec 	 Memory Usage Avg: 4054.67 MB
# 3599999 Lines Processed 	 Line Process Avg: 3403 items/sec 	 Memory Usage Avg: 3961.88 MB
# 3603999 Lines Processed 	 Line Process Avg: 3396 items/sec 	 Memory Usage Avg: 3962.91 MB
# 3607999 Lines Processed 	 Line Process Avg: 3390 items/sec 	 Memory Usage Avg: 3959.84 MB
# 3611999 Lines Processed 	 Line Process Avg: 3385 items/sec 	 Memory Usage Avg: 3918.66 MB
# 3617999 Lines Processed 	 Line Process Avg: 3381 items/sec 	 Memory Usage Avg: 3914.69 MB
# 3622999 Lines Processed 	 Line Process Avg: 3376 items/sec 	 Memory Usage Avg: 3914.02 MB
# 3627999 Lines Processed 	 Line Process Avg: 3371 items/sec 	 Memory Usage Avg: 3913.73 MB
# 3637999 Lines Processed 	 Line Process Avg: 3370 items/sec 	 Memory Usage Avg: 3905.79 MB
# 3645999 Lines Processed 	 Line Process Avg: 3369 items/sec 	 Memory Usage Avg: 3905.58 MB
# 3649999 Lines Processed 	 Line Process Avg: 3363 items/sec 	 Memory Usage Avg: 3953.83 MB
# 3652999 Lines Processed 	 Line Process Avg: 3357 items/sec 	 Memory Usage Avg: 3952.76 MB
# 3655999 Lines Processed 	 Line Process Avg: 3350 items/sec 	 Memory Usage Avg: 3953.22 MB
# 3658999 Lines Processed 	 Line Process Avg: 3344 items/sec 	 Memory Usage Avg: 4006.22 MB
# 3662999 Lines Processed 	 Line Process Avg: 3338 items/sec 	 Memory Usage Avg: 3954.12 MB
# 3665999 Lines Processed 	 Line Process Avg: 3331 items/sec 	 Memory Usage Avg: 4149.23 MB
# 3668999 Lines Processed 	 Line Process Avg: 3325 items/sec 	 Memory Usage Avg: 4095.76 MB
# 3671999 Lines Processed 	 Line Process Avg: 3319 items/sec 	 Memory Usage Avg: 4070.24 MB
# 3674999 Lines Processed 	 Line Process Avg: 3313 items/sec 	 Memory Usage Avg: 4064.47 MB
# 3677999 Lines Processed 	 Line Process Avg: 3306 items/sec 	 Memory Usage Avg: 4073.17 MB
# 3683999 Lines Processed 	 Line Process Avg: 3303 items/sec 	 Memory Usage Avg: 3954.79 MB
# 3694999 Lines Processed 	 Line Process Avg: 3304 items/sec 	 Memory Usage Avg: 3937.89 MB
# 3704999 Lines Processed 	 Line Process Avg: 3304 items/sec 	 Memory Usage Avg: 3935.90 MB
# 3711999 Lines Processed 	 Line Process Avg: 3301 items/sec 	 Memory Usage Avg: 3992.31 MB
# 3715999 Lines Processed 	 Line Process Avg: 3295 items/sec 	 Memory Usage Avg: 3983.24 MB
# 3718999 Lines Processed 	 Line Process Avg: 3289 items/sec 	 Memory Usage Avg: 3984.36 MB
# 3722999 Lines Processed 	 Line Process Avg: 3283 items/sec 	 Memory Usage Avg: 3978.33 MB
# 3726999 Lines Processed 	 Line Process Avg: 3277 items/sec 	 Memory Usage Avg: 3976.64 MB
# 3729999 Lines Processed 	 Line Process Avg: 3272 items/sec 	 Memory Usage Avg: 3983.30 MB
# 3734999 Lines Processed 	 Line Process Avg: 3268 items/sec 	 Memory Usage Avg: 3939.25 MB
# 3738999 Lines Processed 	 Line Process Avg: 3263 items/sec 	 Memory Usage Avg: 3986.14 MB
# 3742999 Lines Processed 	 Line Process Avg: 3256 items/sec 	 Memory Usage Avg: 3981.30 MB
# 3745999 Lines Processed 	 Line Process Avg: 3250 items/sec 	 Memory Usage Avg: 3976.50 MB
# 3749999 Lines Processed 	 Line Process Avg: 3245 items/sec 	 Memory Usage Avg: 3985.63 MB
# 3753999 Lines Processed 	 Line Process Avg: 3238 items/sec 	 Memory Usage Avg: 4017.51 MB
# 3756999 Lines Processed 	 Line Process Avg: 3233 items/sec 	 Memory Usage Avg: 4020.60 MB
# 3760999 Lines Processed 	 Line Process Avg: 3228 items/sec 	 Memory Usage Avg: 3994.70 MB
# 3764999 Lines Processed 	 Line Process Avg: 3224 items/sec 	 Memory Usage Avg: 3994.76 MB
# 3767999 Lines Processed 	 Line Process Avg: 3218 items/sec 	 Memory Usage Avg: 4001.70 MB
# 3770999 Lines Processed 	 Line Process Avg: 3212 items/sec 	 Memory Usage Avg: 4078.73 MB
# 3775999 Lines Processed 	 Line Process Avg: 3206 items/sec 	 Memory Usage Avg: 3999.23 MB
# 3778999 Lines Processed 	 Line Process Avg: 3201 items/sec 	 Memory Usage Avg: 4002.53 MB
# 3781999 Lines Processed 	 Line Process Avg: 3196 items/sec 	 Memory Usage Avg: 4083.98 MB
# 3786999 Lines Processed 	 Line Process Avg: 3192 items/sec 	 Memory Usage Avg: 3995.14 MB
# 3789999 Lines Processed 	 Line Process Avg: 3186 items/sec 	 Memory Usage Avg: 3997.82 MB
# 3793999 Lines Processed 	 Line Process Avg: 3181 items/sec 	 Memory Usage Avg: 4002.44 MB
# 3796999 Lines Processed 	 Line Process Avg: 3176 items/sec 	 Memory Usage Avg: 4002.21 MB
# 3799999 Lines Processed 	 Line Process Avg: 3170 items/sec 	 Memory Usage Avg: 4031.25 MB
# 3803999 Lines Processed 	 Line Process Avg: 3165 items/sec 	 Memory Usage Avg: 4012.44 MB
# 3806999 Lines Processed 	 Line Process Avg: 3160 items/sec 	 Memory Usage Avg: 4019.36 MB
# 3810999 Lines Processed 	 Line Process Avg: 3153 items/sec 	 Memory Usage Avg: 4030.86 MB
# 3813999 Lines Processed 	 Line Process Avg: 3149 items/sec 	 Memory Usage Avg: 4026.12 MB
# 3817999 Lines Processed 	 Line Process Avg: 3144 items/sec 	 Memory Usage Avg: 4019.79 MB
# 3821999 Lines Processed 	 Line Process Avg: 3138 items/sec 	 Memory Usage Avg: 4018.09 MB
# 3825999 Lines Processed 	 Line Process Avg: 3134 items/sec 	 Memory Usage Avg: 4011.76 MB
# 3829999 Lines Processed 	 Line Process Avg: 3130 items/sec 	 Memory Usage Avg: 4014.99 MB
# 3832999 Lines Processed 	 Line Process Avg: 3125 items/sec 	 Memory Usage Avg: 4012.79 MB
# 3836999 Lines Processed 	 Line Process Avg: 3120 items/sec 	 Memory Usage Avg: 4035.73 MB
# 3841999 Lines Processed 	 Line Process Avg: 3115 items/sec 	 Memory Usage Avg: 4014.88 MB
# 3844999 Lines Processed 	 Line Process Avg: 3111 items/sec 	 Memory Usage Avg: 4012.06 MB
# 3849999 Lines Processed 	 Line Process Avg: 3106 items/sec 	 Memory Usage Avg: 4010.55 MB
# 3852999 Lines Processed 	 Line Process Avg: 3102 items/sec 	 Memory Usage Avg: 4053.24 MB
# 3856999 Lines Processed 	 Line Process Avg: 3098 items/sec 	 Memory Usage Avg: 4013.40 MB
# 3860999 Lines Processed 	 Line Process Avg: 3093 items/sec 	 Memory Usage Avg: 4014.87 MB
# 3864999 Lines Processed 	 Line Process Avg: 3089 items/sec 	 Memory Usage Avg: 4016.35 MB
# 3867999 Lines Processed 	 Line Process Avg: 3084 items/sec 	 Memory Usage Avg: 4014.42 MB
# 3871999 Lines Processed 	 Line Process Avg: 3080 items/sec 	 Memory Usage Avg: 4016.00 MB
# 3875999 Lines Processed 	 Line Process Avg: 3076 items/sec 	 Memory Usage Avg: 4011.63 MB
# 3878999 Lines Processed 	 Line Process Avg: 3071 items/sec 	 Memory Usage Avg: 4016.99 MB
# 3882999 Lines Processed 	 Line Process Avg: 3066 items/sec 	 Memory Usage Avg: 4018.58 MB
# 3885999 Lines Processed 	 Line Process Avg: 3062 items/sec 	 Memory Usage Avg: 4025.28 MB
# 3888999 Lines Processed 	 Line Process Avg: 3057 items/sec 	 Memory Usage Avg: 4023.90 MB
# 3891999 Lines Processed 	 Line Process Avg: 3051 items/sec 	 Memory Usage Avg: 4069.04 MB
# 3895999 Lines Processed 	 Line Process Avg: 3047 items/sec 	 Memory Usage Avg: 4024.92 MB
# 3898999 Lines Processed 	 Line Process Avg: 3042 items/sec 	 Memory Usage Avg: 4077.06 MB
# 3902999 Lines Processed 	 Line Process Avg: 3038 items/sec 	 Memory Usage Avg: 4076.29 MB
# 3905999 Lines Processed 	 Line Process Avg: 3033 items/sec 	 Memory Usage Avg: 4082.70 MB
# 3908999 Lines Processed 	 Line Process Avg: 3028 items/sec 	 Memory Usage Avg: 4080.56 MB
# 3912999 Lines Processed 	 Line Process Avg: 3025 items/sec 	 Memory Usage Avg: 4032.27 MB
# 3915999 Lines Processed 	 Line Process Avg: 3020 items/sec 	 Memory Usage Avg: 4048.70 MB
# 3918999 Lines Processed 	 Line Process Avg: 3015 items/sec 	 Memory Usage Avg: 4052.31 MB
# 3922999 Lines Processed 	 Line Process Avg: 3011 items/sec 	 Memory Usage Avg: 4047.68 MB
# 3925999 Lines Processed 	 Line Process Avg: 3007 items/sec 	 Memory Usage Avg: 4045.95 MB
# 3928999 Lines Processed 	 Line Process Avg: 3002 items/sec 	 Memory Usage Avg: 4086.14 MB
# 3932999 Lines Processed 	 Line Process Avg: 2998 items/sec 	 Memory Usage Avg: 4045.50 MB
# 3935999 Lines Processed 	 Line Process Avg: 2993 items/sec 	 Memory Usage Avg: 4047.57 MB
# 3938999 Lines Processed 	 Line Process Avg: 2989 items/sec 	 Memory Usage Avg: 4046.32 MB
# 3942999 Lines Processed 	 Line Process Avg: 2985 items/sec 	 Memory Usage Avg: 4054.95 MB
# 3945999 Lines Processed 	 Line Process Avg: 2980 items/sec 	 Memory Usage Avg: 4045.29 MB
# 3949999 Lines Processed 	 Line Process Avg: 2977 items/sec 	 Memory Usage Avg: 4045.77 MB
# 3953999 Lines Processed 	 Line Process Avg: 2973 items/sec 	 Memory Usage Avg: 4064.86 MB
# 3957999 Lines Processed 	 Line Process Avg: 2969 items/sec 	 Memory Usage Avg: 4066.40 MB
# 3960999 Lines Processed 	 Line Process Avg: 2965 items/sec 	 Memory Usage Avg: 4110.55 MB
# 3964999 Lines Processed 	 Line Process Avg: 2961 items/sec 	 Memory Usage Avg: 4075.88 MB
# 3968999 Lines Processed 	 Line Process Avg: 2956 items/sec 	 Memory Usage Avg: 4076.59 MB
# 3971999 Lines Processed 	 Line Process Avg: 2952 items/sec 	 Memory Usage Avg: 4103.96 MB
# 3975999 Lines Processed 	 Line Process Avg: 2949 items/sec 	 Memory Usage Avg: 4080.58 MB
# 3978999 Lines Processed 	 Line Process Avg: 2944 items/sec 	 Memory Usage Avg: 4144.98 MB
# 3983999 Lines Processed 	 Line Process Avg: 2941 items/sec 	 Memory Usage Avg: 4007.89 MB
# 3987999 Lines Processed 	 Line Process Avg: 2937 items/sec 	 Memory Usage Avg: 4046.59 MB
# 3991999 Lines Processed 	 Line Process Avg: 2934 items/sec 	 Memory Usage Avg: 4041.05 MB
# 3996999 Lines Processed 	 Line Process Avg: 2931 items/sec 	 Memory Usage Avg: 4007.80 MB
# 4002999 Lines Processed 	 Line Process Avg: 2928 items/sec 	 Memory Usage Avg: 4004.96 MB
# 4008999 Lines Processed 	 Line Process Avg: 2926 items/sec 	 Memory Usage Avg: 4003.73 MB
# 4013999 Lines Processed 	 Line Process Avg: 2923 items/sec 	 Memory Usage Avg: 4039.11 MB
# 4018999 Lines Processed 	 Line Process Avg: 2921 items/sec 	 Memory Usage Avg: 4003.60 MB
# 4022999 Lines Processed 	 Line Process Avg: 2917 items/sec 	 Memory Usage Avg: 4039.27 MB
# 4026999 Lines Processed 	 Line Process Avg: 2914 items/sec 	 Memory Usage Avg: 4043.66 MB
# 4031999 Lines Processed 	 Line Process Avg: 2911 items/sec 	 Memory Usage Avg: 4128.48 MB
# 4036999 Lines Processed 	 Line Process Avg: 2907 items/sec 	 Memory Usage Avg: 4045.68 MB
# 4040999 Lines Processed 	 Line Process Avg: 2904 items/sec 	 Memory Usage Avg: 4003.70 MB
# 4044999 Lines Processed 	 Line Process Avg: 2900 items/sec 	 Memory Usage Avg: 4045.87 MB
# 4048999 Lines Processed 	 Line Process Avg: 2897 items/sec 	 Memory Usage Avg: 4071.79 MB
# 4054999 Lines Processed 	 Line Process Avg: 2894 items/sec 	 Memory Usage Avg: 4037.59 MB
# 4057999 Lines Processed 	 Line Process Avg: 2890 items/sec 	 Memory Usage Avg: 4038.47 MB
# 4063999 Lines Processed 	 Line Process Avg: 2889 items/sec 	 Memory Usage Avg: 4003.82 MB
# 4068999 Lines Processed 	 Line Process Avg: 2886 items/sec 	 Memory Usage Avg: 4030.91 MB
# 4074999 Lines Processed 	 Line Process Avg: 2884 items/sec 	 Memory Usage Avg: 4002.99 MB
# 4079999 Lines Processed 	 Line Process Avg: 2881 items/sec 	 Memory Usage Avg: 4003.02 MB
# 4085999 Lines Processed 	 Line Process Avg: 2880 items/sec 	 Memory Usage Avg: 4002.95 MB
# 4089999 Lines Processed 	 Line Process Avg: 2876 items/sec 	 Memory Usage Avg: 4037.31 MB
# 4092999 Lines Processed 	 Line Process Avg: 2872 items/sec 	 Memory Usage Avg: 4044.09 MB
# 4096999 Lines Processed 	 Line Process Avg: 2869 items/sec 	 Memory Usage Avg: 4046.58 MB
# 4100999 Lines Processed 	 Line Process Avg: 2866 items/sec 	 Memory Usage Avg: 4041.12 MB
# 4104999 Lines Processed 	 Line Process Avg: 2863 items/sec 	 Memory Usage Avg: 4039.16 MB
# 4108999 Lines Processed 	 Line Process Avg: 2860 items/sec 	 Memory Usage Avg: 4043.74 MB
# 4112999 Lines Processed 	 Line Process Avg: 2855 items/sec 	 Memory Usage Avg: 4042.54 MB
# 4116999 Lines Processed 	 Line Process Avg: 2852 items/sec 	 Memory Usage Avg: 4046.77 MB
# 4120999 Lines Processed 	 Line Process Avg: 2849 items/sec 	 Memory Usage Avg: 4037.06 MB
# 4124999 Lines Processed 	 Line Process Avg: 2846 items/sec 	 Memory Usage Avg: 4038.93 MB
# 4128999 Lines Processed 	 Line Process Avg: 2843 items/sec 	 Memory Usage Avg: 4041.58 MB
# 4132999 Lines Processed 	 Line Process Avg: 2839 items/sec 	 Memory Usage Avg: 4040.94 MB
# 4136999 Lines Processed 	 Line Process Avg: 2836 items/sec 	 Memory Usage Avg: 4038.27 MB
# 4140999 Lines Processed 	 Line Process Avg: 2833 items/sec 	 Memory Usage Avg: 4002.31 MB
# 4146999 Lines Processed 	 Line Process Avg: 2831 items/sec 	 Memory Usage Avg: 4035.63 MB
# 4151999 Lines Processed 	 Line Process Avg: 2829 items/sec 	 Memory Usage Avg: 4034.60 MB
# 4156999 Lines Processed 	 Line Process Avg: 2826 items/sec 	 Memory Usage Avg: 4036.38 MB
# 4160999 Lines Processed 	 Line Process Avg: 2823 items/sec 	 Memory Usage Avg: 4035.09 MB
# 4165999 Lines Processed 	 Line Process Avg: 2821 items/sec 	 Memory Usage Avg: 4035.03 MB
# 4170999 Lines Processed 	 Line Process Avg: 2818 items/sec 	 Memory Usage Avg: 4002.44 MB
# 4175999 Lines Processed 	 Line Process Avg: 2816 items/sec 	 Memory Usage Avg: 4002.40 MB
# 4180999 Lines Processed 	 Line Process Avg: 2814 items/sec 	 Memory Usage Avg: 4002.31 MB
# 4185999 Lines Processed 	 Line Process Avg: 2811 items/sec 	 Memory Usage Avg: 4002.25 MB
# 4190999 Lines Processed 	 Line Process Avg: 2809 items/sec 	 Memory Usage Avg: 4002.21 MB
# 4195999 Lines Processed 	 Line Process Avg: 2807 items/sec 	 Memory Usage Avg: 4002.18 MB
# 4202999 Lines Processed 	 Line Process Avg: 2804 items/sec 	 Memory Usage Avg: 4028.88 MB
# 4207999 Lines Processed 	 Line Process Avg: 2802 items/sec 	 Memory Usage Avg: 4002.37 MB
# 4213999 Lines Processed 	 Line Process Avg: 2800 items/sec 	 Memory Usage Avg: 4034.54 MB
# 4217999 Lines Processed 	 Line Process Avg: 2798 items/sec 	 Memory Usage Avg: 4002.46 MB
# 4223999 Lines Processed 	 Line Process Avg: 2795 items/sec 	 Memory Usage Avg: 4002.68 MB
# 4228999 Lines Processed 	 Line Process Avg: 2793 items/sec 	 Memory Usage Avg: 4002.77 MB
# 4233999 Lines Processed 	 Line Process Avg: 2791 items/sec 	 Memory Usage Avg: 4002.78 MB
# 4238999 Lines Processed 	 Line Process Avg: 2789 items/sec 	 Memory Usage Avg: 4002.58 MB
# 4244999 Lines Processed 	 Line Process Avg: 2787 items/sec 	 Memory Usage Avg: 4002.40 MB
# 4249999 Lines Processed 	 Line Process Avg: 2785 items/sec 	 Memory Usage Avg: 4002.52 MB
# 4253999 Lines Processed 	 Line Process Avg: 2782 items/sec 	 Memory Usage Avg: 4002.56 MB
# 4258999 Lines Processed 	 Line Process Avg: 2780 items/sec 	 Memory Usage Avg: 4002.68 MB
# 4264999 Lines Processed 	 Line Process Avg: 2778 items/sec 	 Memory Usage Avg: 4035.20 MB
# 4269999 Lines Processed 	 Line Process Avg: 2775 items/sec 	 Memory Usage Avg: 4037.82 MB
# 4272999 Lines Processed 	 Line Process Avg: 2772 items/sec 	 Memory Usage Avg: 4074.48 MB
# 4277999 Lines Processed 	 Line Process Avg: 2770 items/sec 	 Memory Usage Avg: 4036.20 MB
# 4282999 Lines Processed 	 Line Process Avg: 2768 items/sec 	 Memory Usage Avg: 4002.29 MB
# 4287999 Lines Processed 	 Line Process Avg: 2766 items/sec 	 Memory Usage Avg: 4002.38 MB
# 4292999 Lines Processed 	 Line Process Avg: 2763 items/sec 	 Memory Usage Avg: 4002.51 MB
# 4297999 Lines Processed 	 Line Process Avg: 2761 items/sec 	 Memory Usage Avg: 4029.61 MB
# 4303999 Lines Processed 	 Line Process Avg: 2760 items/sec 	 Memory Usage Avg: 4002.54 MB
# 4308999 Lines Processed 	 Line Process Avg: 2758 items/sec 	 Memory Usage Avg: 4002.43 MB
# 4313999 Lines Processed 	 Line Process Avg: 2755 items/sec 	 Memory Usage Avg: 4002.46 MB
# 4319999 Lines Processed 	 Line Process Avg: 2753 items/sec 	 Memory Usage Avg: 4029.70 MB
# 4325999 Lines Processed 	 Line Process Avg: 2752 items/sec 	 Memory Usage Avg: 4002.43 MB
# 4330999 Lines Processed 	 Line Process Avg: 2750 items/sec 	 Memory Usage Avg: 4029.27 MB
# 4336999 Lines Processed 	 Line Process Avg: 2748 items/sec 	 Memory Usage Avg: 4029.07 MB
# 4341999 Lines Processed 	 Line Process Avg: 2747 items/sec 	 Memory Usage Avg: 4028.59 MB
# 4347999 Lines Processed 	 Line Process Avg: 2745 items/sec 	 Memory Usage Avg: 4002.59 MB
# 4352999 Lines Processed 	 Line Process Avg: 2743 items/sec 	 Memory Usage Avg: 4029.66 MB
# 4358999 Lines Processed 	 Line Process Avg: 2742 items/sec 	 Memory Usage Avg: 4002.64 MB
# 4363999 Lines Processed 	 Line Process Avg: 2740 items/sec 	 Memory Usage Avg: 4002.78 MB
# 4369999 Lines Processed 	 Line Process Avg: 2738 items/sec 	 Memory Usage Avg: 4029.09 MB
# 4375999 Lines Processed 	 Line Process Avg: 2737 items/sec 	 Memory Usage Avg: 4028.48 MB
# 4381999 Lines Processed 	 Line Process Avg: 2735 items/sec 	 Memory Usage Avg: 4001.34 MB
# 4387999 Lines Processed 	 Line Process Avg: 2734 items/sec 	 Memory Usage Avg: 4000.39 MB
# 4392999 Lines Processed 	 Line Process Avg: 2732 items/sec 	 Memory Usage Avg: 4000.42 MB
# 4398999 Lines Processed 	 Line Process Avg: 2731 items/sec 	 Memory Usage Avg: 4027.08 MB
# 4404999 Lines Processed 	 Line Process Avg: 2729 items/sec 	 Memory Usage Avg: 4026.73 MB
# 4411999 Lines Processed 	 Line Process Avg: 2729 items/sec 	 Memory Usage Avg: 3999.34 MB
# 4419999 Lines Processed 	 Line Process Avg: 2729 items/sec 	 Memory Usage Avg: 3998.14 MB
# 4426999 Lines Processed 	 Line Process Avg: 2728 items/sec 	 Memory Usage Avg: 3998.26 MB
# 4433999 Lines Processed 	 Line Process Avg: 2727 items/sec 	 Memory Usage Avg: 3997.19 MB
# ...
# 109330999 Lines Processed 	 Line Process Avg: 3259 items/sec 	 Memory Usage Avg: 3660.53 MB
# 109342999 Lines Processed 	 Line Process Avg: 3259 items/sec 	 Memory Usage Avg: 3659.29 MB
# 109356999 Lines Processed 	 Line Process Avg: 3259 items/sec 	 Memory Usage Avg: 3659.25 MB
# 109367999 Lines Processed 	 Line Process Avg: 3259 items/sec 	 Memory Usage Avg: 3659.37 MB
# 109387999 Lines Processed 	 Line Process Avg: 3259 items/sec 	 Memory Usage Avg: 3656.41 MB
# 109402999 Lines Processed 	 Line Process Avg: 3260 items/sec 	 Memory Usage Avg: 3655.48 MB
# 109416999 Lines Processed 	 Line Process Avg: 3260 items/sec 	 Memory Usage Avg: 3655.69 MB
# 109426999 Lines Processed 	 Line Process Avg: 3260 items/sec 	 Memory Usage Avg: 3655.36 MB
# 109445999 Lines Processed 	 Line Process Avg: 3260 items/sec 	 Memory Usage Avg: 3654.36 MB
# 109461999 Lines Processed 	 Line Process Avg: 3260 items/sec 	 Memory Usage Avg: 3654.26 MB
# 109478999 Lines Processed 	 Line Process Avg: 3260 items/sec 	 Memory Usage Avg: 3654.55 MB
# 109491999 Lines Processed 	 Line Process Avg: 3260 items/sec 	 Memory Usage Avg: 3654.63 MB
# 109504999 Lines Processed 	 Line Process Avg: 3261 items/sec 	 Memory Usage Avg: 3654.61 MB
# 109519999 Lines Processed 	 Line Process Avg: 3261 items/sec 	 Memory Usage Avg: 3653.63 MB
# 109535999 Lines Processed 	 Line Process Avg: 3261 items/sec 	 Memory Usage Avg: 3652.53 MB
# 109549999 Lines Processed 	 Line Process Avg: 3261 items/sec 	 Memory Usage Avg: 3652.52 MB
# 109561999 Lines Processed 	 Line Process Avg: 3261 items/sec 	 Memory Usage Avg: 3652.57 MB
# 109576999 Lines Processed 	 Line Process Avg: 3261 items/sec 	 Memory Usage Avg: 3650.55 MB
# 109595999 Lines Processed 	 Line Process Avg: 3261 items/sec 	 Memory Usage Avg: 3646.49 MB
# 109618999 Lines Processed 	 Line Process Avg: 3262 items/sec 	 Memory Usage Avg: 3640.54 MB
# 109635999 Lines Processed 	 Line Process Avg: 3262 items/sec 	 Memory Usage Avg: 3639.61 MB
# 109656999 Lines Processed 	 Line Process Avg: 3262 items/sec 	 Memory Usage Avg: 3638.61 MB
# 109673999 Lines Processed 	 Line Process Avg: 3263 items/sec 	 Memory Usage Avg: 3638.61 MB
# 109690999 Lines Processed 	 Line Process Avg: 3263 items/sec 	 Memory Usage Avg: 3636.56 MB
# 109701999 Lines Processed 	 Line Process Avg: 3263 items/sec 	 Memory Usage Avg: 3635.84 MB
# 109711999 Lines Processed 	 Line Process Avg: 3263 items/sec 	 Memory Usage Avg: 3635.00 MB
# 109724999 Lines Processed 	 Line Process Avg: 3263 items/sec 	 Memory Usage Avg: 3634.74 MB
# 109741999 Lines Processed 	 Line Process Avg: 3263 items/sec 	 Memory Usage Avg: 3633.69 MB
# 109758999 Lines Processed 	 Line Process Avg: 3263 items/sec 	 Memory Usage Avg: 3633.69 MB
# 109776999 Lines Processed 	 Line Process Avg: 3264 items/sec 	 Memory Usage Avg: 3632.69 MB
# 109791999 Lines Processed 	 Line Process Avg: 3264 items/sec 	 Memory Usage Avg: 3630.76 MB
# 109804999 Lines Processed 	 Line Process Avg: 3264 items/sec 	 Memory Usage Avg: 3626.93 MB
# 109815999 Lines Processed 	 Line Process Avg: 3264 items/sec 	 Memory Usage Avg: 3623.18 MB
# 109831999 Lines Processed 	 Line Process Avg: 3264 items/sec 	 Memory Usage Avg: 3620.14 MB
# 109853999 Lines Processed 	 Line Process Avg: 3265 items/sec 	 Memory Usage Avg: 3619.16 MB
# 109875999 Lines Processed 	 Line Process Avg: 3265 items/sec 	 Memory Usage Avg: 3618.16 MB
# 109893999 Lines Processed 	 Line Process Avg: 3265 items/sec 	 Memory Usage Avg: 3618.16 MB
# 109912999 Lines Processed 	 Line Process Avg: 3265 items/sec 	 Memory Usage Avg: 3615.28 MB
# 109932999 Lines Processed 	 Line Process Avg: 3266 items/sec 	 Memory Usage Avg: 3613.28 MB
# 109953999 Lines Processed 	 Line Process Avg: 3266 items/sec 	 Memory Usage Avg: 3611.39 MB
# 109972999 Lines Processed 	 Line Process Avg: 3266 items/sec 	 Memory Usage Avg: 3610.39 MB
# 109988999 Lines Processed 	 Line Process Avg: 3266 items/sec 	 Memory Usage Avg: 3609.42 MB
# 110008999 Lines Processed 	 Line Process Avg: 3267 items/sec 	 Memory Usage Avg: 3607.42 MB
# 110029999 Lines Processed 	 Line Process Avg: 3267 items/sec 	 Memory Usage Avg: 3606.42 MB
# 110054999 Lines Processed 	 Line Process Avg: 3268 items/sec 	 Memory Usage Avg: 3605.42 MB
# 110077999 Lines Processed 	 Line Process Avg: 3268 items/sec 	 Memory Usage Avg: 3603.50 MB
# 110101999 Lines Processed 	 Line Process Avg: 3268 items/sec 	 Memory Usage Avg: 3596.50 MB
# 110124999 Lines Processed 	 Line Process Avg: 3269 items/sec 	 Memory Usage Avg: 3591.52 MB
# 110145999 Lines Processed 	 Line Process Avg: 3269 items/sec 	 Memory Usage Avg: 3591.52 MB
# 110185999 Lines Processed 	 Line Process Avg: 3270 items/sec 	 Memory Usage Avg: 3587.52 MB
# 110203999 Lines Processed 	 Line Process Avg: 3270 items/sec 	 Memory Usage Avg: 3587.33 MB
# 110224999 Lines Processed 	 Line Process Avg: 3271 items/sec 	 Memory Usage Avg: 3587.33 MB
# 110233999 Lines Processed 	 Line Process Avg: 3270 items/sec 	 Memory Usage Avg: 3853.51 MB
# 110240999 Lines Processed 	 Line Process Avg: 3270 items/sec 	 Memory Usage Avg: 3865.29 MB
# 110250999 Lines Processed 	 Line Process Avg: 3270 items/sec 	 Memory Usage Avg: 3681.38 MB
# 110262999 Lines Processed 	 Line Process Avg: 3270 items/sec 	 Memory Usage Avg: 3687.38 MB
# 110285999 Lines Processed 	 Line Process Avg: 3271 items/sec 	 Memory Usage Avg: 3671.50 MB
# 110313999 Lines Processed 	 Line Process Avg: 3271 items/sec 	 Memory Usage Avg: 3658.50 MB
# 110332999 Lines Processed 	 Line Process Avg: 3272 items/sec 	 Memory Usage Avg: 3656.50 MB
# 110351999 Lines Processed 	 Line Process Avg: 3272 items/sec 	 Memory Usage Avg: 3654.50 MB
# 110373999 Lines Processed 	 Line Process Avg: 3272 items/sec 	 Memory Usage Avg: 3649.50 MB
# 110390999 Lines Processed 	 Line Process Avg: 3273 items/sec 	 Memory Usage Avg: 3648.45 MB
# 110410999 Lines Processed 	 Line Process Avg: 3273 items/sec 	 Memory Usage Avg: 3647.45 MB
# 110430999 Lines Processed 	 Line Process Avg: 3273 items/sec 	 Memory Usage Avg: 3636.62 MB
# 110446999 Lines Processed 	 Line Process Avg: 3273 items/sec 	 Memory Usage Avg: 3635.49 MB
# 110469999 Lines Processed 	 Line Process Avg: 3274 items/sec 	 Memory Usage Avg: 3633.49 MB
# 110489999 Lines Processed 	 Line Process Avg: 3274 items/sec 	 Memory Usage Avg: 3629.54 MB
# 110499999 Lines Processed 	 Line Process Avg: 3274 items/sec 	 Memory Usage Avg: 3628.58 MB
# 110516999 Lines Processed 	 Line Process Avg: 3274 items/sec 	 Memory Usage Avg: 3628.58 MB
# 110527999 Lines Processed 	 Line Process Avg: 3274 items/sec 	 Memory Usage Avg: 3628.45 MB
# 110539999 Lines Processed 	 Line Process Avg: 3274 items/sec 	 Memory Usage Avg: 3628.57 MB
# 110551999 Lines Processed 	 Line Process Avg: 3274 items/sec 	 Memory Usage Avg: 3628.55 MB
# 110569999 Lines Processed 	 Line Process Avg: 3275 items/sec 	 Memory Usage Avg: 3625.40 MB
# 110586999 Lines Processed 	 Line Process Avg: 3275 items/sec 	 Memory Usage Avg: 3624.40 MB
# 110597999 Lines Processed 	 Line Process Avg: 3275 items/sec 	 Memory Usage Avg: 3624.51 MB
# 110610999 Lines Processed 	 Line Process Avg: 3275 items/sec 	 Memory Usage Avg: 3624.37 MB
# 110630999 Lines Processed 	 Line Process Avg: 3275 items/sec 	 Memory Usage Avg: 3620.37 MB
# 110648999 Lines Processed 	 Line Process Avg: 3275 items/sec 	 Memory Usage Avg: 3616.46 MB
# 110664999 Lines Processed 	 Line Process Avg: 3276 items/sec 	 Memory Usage Avg: 3615.55 MB
# 110677999 Lines Processed 	 Line Process Avg: 3276 items/sec 	 Memory Usage Avg: 3613.52 MB
# 110688999 Lines Processed 	 Line Process Avg: 3276 items/sec 	 Memory Usage Avg: 3612.63 MB
# 110699999 Lines Processed 	 Line Process Avg: 3276 items/sec 	 Memory Usage Avg: 3612.44 MB
# 110719999 Lines Processed 	 Line Process Avg: 3276 items/sec 	 Memory Usage Avg: 3601.71 MB
# 110740999 Lines Processed 	 Line Process Avg: 3276 items/sec 	 Memory Usage Avg: 3598.71 MB
# 110754999 Lines Processed 	 Line Process Avg: 3277 items/sec 	 Memory Usage Avg: 3598.30 MB
# 110769999 Lines Processed 	 Line Process Avg: 3277 items/sec 	 Memory Usage Avg: 3598.39 MB
# 110782999 Lines Processed 	 Line Process Avg: 3277 items/sec 	 Memory Usage Avg: 3597.40 MB
# 110797999 Lines Processed 	 Line Process Avg: 3277 items/sec 	 Memory Usage Avg: 3595.33 MB
# 110812999 Lines Processed 	 Line Process Avg: 3277 items/sec 	 Memory Usage Avg: 3595.54 MB
# 110822999 Lines Processed 	 Line Process Avg: 3277 items/sec 	 Memory Usage Avg: 3595.22 MB
# 110836999 Lines Processed 	 Line Process Avg: 3277 items/sec 	 Memory Usage Avg: 3595.22 MB
# 110854999 Lines Processed 	 Line Process Avg: 3277 items/sec 	 Memory Usage Avg: 3595.18 MB
# 110876999 Lines Processed 	 Line Process Avg: 3278 items/sec 	 Memory Usage Avg: 3593.38 MB
# 110909999 Lines Processed 	 Line Process Avg: 3279 items/sec 	 Memory Usage Avg: 3589.52 MB
# 110931999 Lines Processed 	 Line Process Avg: 3279 items/sec 	 Memory Usage Avg: 3585.51 MB
# 110958999 Lines Processed 	 Line Process Avg: 3279 items/sec 	 Memory Usage Avg: 3584.51 MB
# 110985999 Lines Processed 	 Line Process Avg: 3280 items/sec 	 Memory Usage Avg: 3583.51 MB
# 111004999 Lines Processed 	 Line Process Avg: 3280 items/sec 	 Memory Usage Avg: 3581.68 MB
# 111037999 Lines Processed 	 Line Process Avg: 3281 items/sec 	 Memory Usage Avg: 3580.68 MB
# 111070999 Lines Processed 	 Line Process Avg: 3282 items/sec 	 Memory Usage Avg: 3580.68 MB
# 111094999 Lines Processed 	 Line Process Avg: 3282 items/sec 	 Memory Usage Avg: 3579.69 MB
# 111114999 Lines Processed 	 Line Process Avg: 3282 items/sec 	 Memory Usage Avg: 3579.69 MB
# 111132999 Lines Processed 	 Line Process Avg: 3283 items/sec 	 Memory Usage Avg: 3579.69 MB
# 111158999 Lines Processed 	 Line Process Avg: 3283 items/sec 	 Memory Usage Avg: 3579.69 MB
# 111183999 Lines Processed 	 Line Process Avg: 3283 items/sec 	 Memory Usage Avg: 3579.69 MB
# 111206999 Lines Processed 	 Line Process Avg: 3284 items/sec 	 Memory Usage Avg: 3578.62 MB
# 111230999 Lines Processed 	 Line Process Avg: 3284 items/sec 	 Memory Usage Avg: 3577.62 MB
# 111252999 Lines Processed 	 Line Process Avg: 3285 items/sec 	 Memory Usage Avg: 3577.62 MB
# 111274999 Lines Processed 	 Line Process Avg: 3285 items/sec 	 Memory Usage Avg: 3577.62 MB
# 111295999 Lines Processed 	 Line Process Avg: 3285 items/sec 	 Memory Usage Avg: 3577.62 MB
# 111316999 Lines Processed 	 Line Process Avg: 3286 items/sec 	 Memory Usage Avg: 3576.74 MB
# 111335999 Lines Processed 	 Line Process Avg: 3286 items/sec 	 Memory Usage Avg: 3576.74 MB
# 111354999 Lines Processed 	 Line Process Avg: 3286 items/sec 	 Memory Usage Avg: 3576.74 MB
# 111374999 Lines Processed 	 Line Process Avg: 3286 items/sec 	 Memory Usage Avg: 3576.74 MB
# 111395999 Lines Processed 	 Line Process Avg: 3287 items/sec 	 Memory Usage Avg: 3576.74 MB
# 111418999 Lines Processed 	 Line Process Avg: 3287 items/sec 	 Memory Usage Avg: 3574.74 MB
# 111439999 Lines Processed 	 Line Process Avg: 3287 items/sec 	 Memory Usage Avg: 3573.62 MB
# 111462999 Lines Processed 	 Line Process Avg: 3288 items/sec 	 Memory Usage Avg: 3572.62 MB
# 111484999 Lines Processed 	 Line Process Avg: 3288 items/sec 	 Memory Usage Avg: 3572.62 MB
# 111505999 Lines Processed 	 Line Process Avg: 3289 items/sec 	 Memory Usage Avg: 3572.62 MB
# 111526999 Lines Processed 	 Line Process Avg: 3289 items/sec 	 Memory Usage Avg: 3572.62 MB
# 111539999 Lines Processed 	 Line Process Avg: 3289 items/sec 	 Memory Usage Avg: 3572.62 MB
# 111557999 Lines Processed 	 Line Process Avg: 3289 items/sec 	 Memory Usage Avg: 3572.62 MB
# 111576999 Lines Processed 	 Line Process Avg: 3289 items/sec 	 Memory Usage Avg: 3572.69 MB
# 111599999 Lines Processed 	 Line Process Avg: 3290 items/sec 	 Memory Usage Avg: 3570.65 MB
# 111620999 Lines Processed 	 Line Process Avg: 3290 items/sec 	 Memory Usage Avg: 3569.65 MB
# 111637999 Lines Processed 	 Line Process Avg: 3290 items/sec 	 Memory Usage Avg: 3569.67 MB
# 111656999 Lines Processed 	 Line Process Avg: 3291 items/sec 	 Memory Usage Avg: 3569.67 MB
# 111674999 Lines Processed 	 Line Process Avg: 3291 items/sec 	 Memory Usage Avg: 3568.67 MB
# 111698999 Lines Processed 	 Line Process Avg: 3291 items/sec 	 Memory Usage Avg: 3567.67 MB
# 111727999 Lines Processed 	 Line Process Avg: 3292 items/sec 	 Memory Usage Avg: 3566.67 MB
# 111755999 Lines Processed 	 Line Process Avg: 3292 items/sec 	 Memory Usage Avg: 3565.66 MB
# 111786999 Lines Processed 	 Line Process Avg: 3293 items/sec 	 Memory Usage Avg: 3561.66 MB
# 111820999 Lines Processed 	 Line Process Avg: 3294 items/sec 	 Memory Usage Avg: 3559.66 MB
# 111845999 Lines Processed 	 Line Process Avg: 3294 items/sec 	 Memory Usage Avg: 3558.66 MB
# 111870999 Lines Processed 	 Line Process Avg: 3295 items/sec 	 Memory Usage Avg: 3558.66 MB
# 111895999 Lines Processed 	 Line Process Avg: 3295 items/sec 	 Memory Usage Avg: 3558.66 MB
# 111918999 Lines Processed 	 Line Process Avg: 3295 items/sec 	 Memory Usage Avg: 3557.66 MB
# 111938999 Lines Processed 	 Line Process Avg: 3296 items/sec 	 Memory Usage Avg: 3557.66 MB
# 111953999 Lines Processed 	 Line Process Avg: 3296 items/sec 	 Memory Usage Avg: 3557.66 MB
# 111971999 Lines Processed 	 Line Process Avg: 3296 items/sec 	 Memory Usage Avg: 3555.66 MB
# 111989999 Lines Processed 	 Line Process Avg: 3296 items/sec 	 Memory Usage Avg: 3555.66 MB
# 112007999 Lines Processed 	 Line Process Avg: 3297 items/sec 	 Memory Usage Avg: 3555.66 MB
# 112028999 Lines Processed 	 Line Process Avg: 3297 items/sec 	 Memory Usage Avg: 3554.66 MB
# 112048999 Lines Processed 	 Line Process Avg: 3297 items/sec 	 Memory Usage Avg: 3553.76 MB
# 112070999 Lines Processed 	 Line Process Avg: 3298 items/sec 	 Memory Usage Avg: 3553.76 MB
# 112086999 Lines Processed 	 Line Process Avg: 3298 items/sec 	 Memory Usage Avg: 3553.63 MB
# 112103999 Lines Processed 	 Line Process Avg: 3298 items/sec 	 Memory Usage Avg: 3553.63 MB
# 112121999 Lines Processed 	 Line Process Avg: 3298 items/sec 	 Memory Usage Avg: 3553.63 MB
# 112138999 Lines Processed 	 Line Process Avg: 3298 items/sec 	 Memory Usage Avg: 3553.63 MB
# 112158999 Lines Processed 	 Line Process Avg: 3299 items/sec 	 Memory Usage Avg: 3553.63 MB
# 112179999 Lines Processed 	 Line Process Avg: 3299 items/sec 	 Memory Usage Avg: 3553.63 MB
# 112194999 Lines Processed 	 Line Process Avg: 3299 items/sec 	 Memory Usage Avg: 3553.63 MB
# 112209999 Lines Processed 	 Line Process Avg: 3299 items/sec 	 Memory Usage Avg: 3553.63 MB
# 112223999 Lines Processed 	 Line Process Avg: 3299 items/sec 	 Memory Usage Avg: 3553.63 MB
# 112239999 Lines Processed 	 Line Process Avg: 3300 items/sec 	 Memory Usage Avg: 3553.63 MB
# 112254999 Lines Processed 	 Line Process Avg: 3300 items/sec 	 Memory Usage Avg: 3553.63 MB
# 112271999 Lines Processed 	 Line Process Avg: 3300 items/sec 	 Memory Usage Avg: 3552.63 MB
# 112284999 Lines Processed 	 Line Process Avg: 3300 items/sec 	 Memory Usage Avg: 3552.63 MB
# 112299999 Lines Processed 	 Line Process Avg: 3300 items/sec 	 Memory Usage Avg: 3552.63 MB
# 112312999 Lines Processed 	 Line Process Avg: 3300 items/sec 	 Memory Usage Avg: 3552.63 MB
# 112324999 Lines Processed 	 Line Process Avg: 3300 items/sec 	 Memory Usage Avg: 3552.70 MB
# 112338999 Lines Processed 	 Line Process Avg: 3300 items/sec 	 Memory Usage Avg: 3552.70 MB
# 112356999 Lines Processed 	 Line Process Avg: 3301 items/sec 	 Memory Usage Avg: 3552.70 MB
# 112373999 Lines Processed 	 Line Process Avg: 3301 items/sec 	 Memory Usage Avg: 3552.70 MB
# 112386999 Lines Processed 	 Line Process Avg: 3301 items/sec 	 Memory Usage Avg: 3552.70 MB
# 112399999 Lines Processed 	 Line Process Avg: 3301 items/sec 	 Memory Usage Avg: 3552.70 MB
# 112411999 Lines Processed 	 Line Process Avg: 3301 items/sec 	 Memory Usage Avg: 3552.70 MB
# 112424999 Lines Processed 	 Line Process Avg: 3301 items/sec 	 Memory Usage Avg: 3552.70 MB
# 112437999 Lines Processed 	 Line Process Avg: 3301 items/sec 	 Memory Usage Avg: 3552.70 MB
# 112451999 Lines Processed 	 Line Process Avg: 3301 items/sec 	 Memory Usage Avg: 3552.70 MB
# 112466999 Lines Processed 	 Line Process Avg: 3302 items/sec 	 Memory Usage Avg: 3550.70 MB
# 112473858 Lines Processed 	 Line Process Avg: 3302 items/sec 	 Memory Usage Avg: 3494.30 MB

# %% [markdown]
# ### Adding entities (label, description, claims, and aliases) of IDs found in WikidataID to WikidataEntity

# %%
import sys
sys.path.append('../src')

from wikidata_dumpreader import WikidataDumpReader
from wikidataDB import WikidataID, WikidataEntity
from multiprocessing import Lock
import json
from tqdm import tqdm
import psutil

FILEPATH = '../data/Wikidata/latest-all.json.bz2'
BATCH_SIZE = 1000
NUM_PROCESSES = 6
skiplines = 0
wikidata = WikidataDumpReader(FILEPATH, num_processes=NUM_PROCESSES, batch_size=BATCH_SIZE, skiplines=skiplines)

def remove_keys(data, keys_to_remove=['hash', 'property', 'numeric-id', 'qualifiers-order']):
    if isinstance(data, dict):
        return {
            key: remove_keys(value, keys_to_remove)
            for key, value in data.items() if key not in keys_to_remove
        }
    elif isinstance(data, list):
        return [remove_keys(item, keys_to_remove) for item in data]
    else:
        return data

def get_claims(item):
    claims = {}
    if 'claims' in item:
        for pid,x in item['claims'].items():
            pid_claims = []
            for i in x:
                if (i['type'] == 'statement') and (i['rank'] != 'deprecated'):
                    pid_claims.append({
                        'mainsnak': remove_keys(i['mainsnak']) if 'mainsnak' in i else {},
                        'qualifiers': remove_keys(i['qualifiers']) if 'qualifiers' in i else {},
                        'rank': i['rank']
                    })
            if len(pid_claims) > 0:
                claims[pid] = pid_claims
    return claims

def get_aliases(item):
    aliases = set()
    if language in item['aliases']:
        aliases = set([x['value'] for x in item['aliases'][language]])
    if 'mul' in item['aliases']:
        aliases = aliases | set([x['value'] for x in item['aliases']['mul']])
    return list(aliases)

data_batch = []
progressbar = tqdm(total=12327824, desc="Running...")
progressbar.update(skiplines)
sqlitDBlock = Lock()
language = 'en'
def save_entites_to_sqlite(item):
    global data_batch

    if item is not None:
        if WikidataID.get_id(item['id']):
            label = item['labels'][language]['value'] if (language in item['labels']) else (item['labels']['mul']['value'] if ('mul' in item['labels']) else '')
            description = item['descriptions'][language]['value'] if (language in item['descriptions']) else (item['descriptions']['mul']['value'] if ('mul' in item['descriptions']) else '')
            aliases = get_aliases(item)
            claims = get_claims(item)
            data_batch.append({
                'id': item['id'],
                'label': label,
                'description': description,
                'aliases': json.dumps(aliases, separators=(',', ':')),
                'claims': json.dumps(claims, separators=(',', ':')),
            })
            progressbar.update(1)

            process = psutil.Process()
            progressbar.set_description(f"Batch Size: {len(data_batch)} \t Memory Usage: {process.memory_info().rss / 1024 ** 2:.2f} MB")
            with sqlitDBlock:
                if len(data_batch) >= BATCH_SIZE:
                    worked = WikidataEntity.add_bulk_entities(data_batch)
                    if worked:
                        data_batch = []

async def run_processor():
    await wikidata.run(save_entites_to_sqlite, max_iterations=None, verbose=False)

await run_processor()

progressbar.close()
if len(data_batch) > 0:
    WikidataEntity.add_bulk_entities(data_batch)
# Out:
# 0it [00:00, ?it/s]         | 0/12327824 [00:00<?, ?it/s]
# Batch Size: 650 	 Memory Usage: 5114.11 MB:  35%|███▍      | 4305154/12327824 [4:58:46<243:29:06,  9.15it/s]

# %%
import sys
sys.path.append('../src')

from wikidata_dumpreader import WikidataDumpReader
from wikidataDB import WikidataID, WikidataEntity
from multiprocessing import Lock
import json
from tqdm import tqdm
import psutil

FILEPATH = '../data/Wikidata/latest-all.json.bz2'
BATCH_SIZE = 10000
NUM_PROCESSES = 4
skiplines = 0
wikidata = WikidataDumpReader(FILEPATH, num_processes=NUM_PROCESSES, batch_size=BATCH_SIZE, skiplines=skiplines)

def in_mul_and_not_en(item):
    return ('sitelinks' in item) and (f'{language}wiki' in item['sitelinks']) and (((language not in item['labels']) and ('mul' in item['labels'])) or ((language not in item['descriptions']) and ('mul' in item['descriptions'])))

def remove_keys(data, keys_to_remove=['hash', 'property', 'numeric-id', 'qualifiers-order']):
    if isinstance(data, dict):
        return {
            key: remove_keys(value, keys_to_remove)
            for key, value in data.items() if key not in keys_to_remove
        }
    elif isinstance(data, list):
        return [remove_keys(item, keys_to_remove) for item in data]
    else:
        return data

def get_claims(item):
    claims = {}
    if 'claims' in item:
        for pid,x in item['claims'].items():
            pid_claims = []
            for i in x:
                if (i['type'] == 'statement') and (i['rank'] != 'deprecated'):
                    pid_claims.append({
                        'mainsnak': remove_keys(i['mainsnak']) if 'mainsnak' in i else {},
                        'qualifiers': remove_keys(i['qualifiers']) if 'qualifiers' in i else {},
                        'rank': i['rank']
                    })
            if len(pid_claims) > 0:
                claims[pid] = pid_claims
    return claims

def get_aliases(item):
    aliases = set()
    if language in item['aliases']:
        aliases = set([x['value'] for x in item['aliases'][language]])
    if 'mul' in item['aliases']:
        aliases = aliases | set([x['value'] for x in item['aliases']['mul']])
    return list(aliases)

data_batch = []
progressbar = tqdm(total=112473858)
sqlitDBlock = Lock()
language = 'en'
def save_entites_to_sqlite(item):
    global data_batch
    global missing_ids
    global IDtypes

    progressbar.update(1)
    if item is not None:
        if (item['id'] in missing_ids):
            label = item['labels'][language]['value'] if (language in item['labels']) else (item['labels']['mul']['value'] if ('mul' in item['labels']) else '')
            description = item['descriptions'][language]['value'] if (language in item['descriptions']) else (item['descriptions']['mul']['value'] if ('mul' in item['descriptions']) else '')
            aliases = get_aliases(item)
            claims = get_claims(item)
            data_batch.append({
                'id': item['id'],
                'label': label,
                'description': description,
                'aliases': json.dumps(aliases, separators=(',', ':')),
                'claims': json.dumps(claims, separators=(',', ':')),
            })

            process = psutil.Process()
            progressbar.set_description(f"Batch Size: {len(data_batch)} \t Memory Usage: {process.memory_info().rss / 1024 ** 2:.2f} MB")
            with sqlitDBlock:
                if len(data_batch) >= 1:
                    worked = WikidataEntity.add_bulk_entities(data_batch)
                    if worked:
                        data_batch = []

async def run_processor():
    await wikidata.run(save_entites_to_sqlite, max_iterations=None, verbose=False)

await run_processor()

progressbar.close()
if len(data_batch) > 0:
    WikidataEntity.add_bulk_entities(data_batch)
# Out:
# 100%|██████████| 112473858/112473858 [8:49:46<00:00, 3538.45it/s]

# %% [markdown]
# ### Find IDs that are in WikidataID but not in WikidataEntity

# %%
import sys
sys.path.append('../src')

from sqlalchemy import select
from wikidataDB import Session, WikidataID, WikidataEntity

with Session() as session:
    result = session.execute(
        select(WikidataID.id)
        .outerjoin(WikidataEntity, WikidataID.id == WikidataEntity.id)
        .filter(WikidataEntity.id == None)
        .filter(WikidataID.in_wikipedia == True)
    )
    missing_ids = set(result.scalars().all())

print(len(missing_ids))

# %% [markdown]
# ### Find IDs that are not in WikidataEntity but are in the claims, qualifiers, and quantity units of entities connected to Wikipedia

# %%
import sys
sys.path.append('../src')

from wikidataDB import Session, WikidataID, WikidataEntity
from tqdm import tqdm

def get_missing_entities(session, ids):
    existing_entities = session.query(WikidataEntity.id).filter(WikidataEntity.id.in_(ids)).all()
    existing_ids = {entity.id for entity in existing_entities}
    return set(ids) - existing_ids

with Session() as session:
    entities = session.query(WikidataEntity).join(WikidataID, WikidataEntity.id == WikidataID.id).filter(WikidataID.in_wikipedia == True).yield_per(100000)

    progressbar = tqdm(total=9203531)
    found = False
    missing_ids = set()

    batch_size = 10000
    ids_to_check = set()

    for entity in entities:
        progressbar.update(1)
        for pid, claim in entity.claims.items():
            ids_to_check.add(pid)
            for c in claim:
                if ('datavalue' in c['mainsnak']):
                    if ((c['mainsnak']['datatype'] == 'wikibase-item') or (c['mainsnak']['datatype'] == 'wikibase-property')):
                        id = c['mainsnak']['datavalue']['value']['id']
                        ids_to_check.add(id)
                    elif (c['mainsnak']['datatype'] == 'quantity') and (c['mainsnak']['datavalue']['value']['unit'] != '1'):
                        id = c['mainsnak']['datavalue']['value']['unit'].rsplit('/', 1)[1]
                        ids_to_check.add(id)

                if 'qualifiers' in c:
                    for pid, qualifier in c['qualifiers'].items():
                        ids_to_check.add(pid)
                        for q in qualifier:
                            if ('datavalue' in q):
                                if ((q['datatype'] == 'wikibase-item') or (q['datatype'] == 'wikibase-property')):
                                    id = q['datavalue']['value']['id']
                                    ids_to_check.add(id)
                                elif (q['datatype'] == 'quantity') and (q['datavalue']['value']['unit'] != '1'):
                                    id = q['datavalue']['value']['unit'].rsplit('/', 1)[1]
                                    ids_to_check.add(id)


        if len(ids_to_check) >= batch_size:
            missing_ids.update(get_missing_entities(session, ids_to_check))
            ids_to_check.clear()

        if progressbar.n % 1000 == 0:
            progressbar.set_description(f"Missing IDs: {len(missing_ids)}")

    if ids_to_check:
        missing_ids.update(get_missing_entities(session, ids_to_check))

    progressbar.close()
